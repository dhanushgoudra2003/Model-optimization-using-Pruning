# %%
#PREPROCESSING

# %%
import os
from PIL import Image
import numpy as np

def preprocess_images(input_directory, output_directory, target_size=(224, 224), to_grayscale=True):
    image_count = 0

    for root, dirs, files in os.walk(input_directory):
        for filename in files:
            file_path = os.path.join(root, filename)

            try:
                image = Image.open(file_path)

                image = image.resize(target_size)

                if to_grayscale:
                    image = image.convert('L')

                image_array = np.array(image) / 255.0

                relative_path = os.path.relpath(root, input_directory)
                output_folder = os.path.join(output_directory, relative_path)
                if not os.path.exists(output_folder):
                    os.makedirs(output_folder)

                output_path = os.path.join(output_folder, filename)
                Image.fromarray((image_array * 255).astype(np.uint8)).save(output_path)  # Save as uint8

                image_count += 1

                print(f"Processed and saved: {filename} to {output_path}")

            except Exception as e:
                print(f"Error processing image {file_path}: {e}")

    print(f"Total number of images processed: {image_count}")

# Example usage
input_directory = r'C:\Users\Asus\Desktop\archive(3)'
output_directory = r'"C:\Users\Asus\Desktop\Pre-processed'

preprocess_images(input_directory, output_directory)
# Out:
# Processed and saved: 220.jpg to C:\Users\Asus\Desktop\Pre\test\altar\220.jpg
# Processed and saved: 221.jpg to C:\Users\Asus\Desktop\Pre\test\altar\221.jpg
# Processed and saved: 222.jpg to C:\Users\Asus\Desktop\Pre\test\altar\222.jpg
# Processed and saved: 223.jpg to C:\Users\Asus\Desktop\Pre\test\altar\223.jpg
# Processed and saved: 224.jpg to C:\Users\Asus\Desktop\Pre\test\altar\224.jpg
# Processed and saved: 225.jpg to C:\Users\Asus\Desktop\Pre\test\altar\225.jpg
# Processed and saved: 226.jpg to C:\Users\Asus\Desktop\Pre\test\altar\226.jpg
# Processed and saved: 227.jpg to C:\Users\Asus\Desktop\Pre\test\altar\227.jpg
# Processed and saved: 228.jpg to C:\Users\Asus\Desktop\Pre\test\altar\228.jpg
# Processed and saved: 229.jpg to C:\Users\Asus\Desktop\Pre\test\altar\229.jpg
# Processed and saved: 230.jpg to C:\Users\Asus\Desktop\Pre\test\altar\230.jpg
# Processed and saved: 231.jpg to C:\Users\Asus\Desktop\Pre\test\altar\231.jpg
# Processed and saved: 232.jpg to C:\Users\Asus\Desktop\Pre\test\altar\232.jpg
# Processed and saved: 233.jpg to C:\Users\Asus\Desktop\Pre\test\altar\233.jpg
# Processed and saved: 234.jpg to C:\Users\Asus\Desktop\Pre\test\altar\234.jpg
# Processed and saved: 235.jpg to C:\Users\Asus\Desktop\Pre\test\altar\235.jpg
# Processed and saved: 236.jpg to C:\Users\Asus\Desktop\Pre\test\altar\236.jpg
# Processed and saved: 237.jpg to C:\Users\Asus\Desktop\Pre\test\altar\237.jpg
# Processed and saved: 238.jpg to C:\Users\Asus\Desktop\Pre\test\altar\238.jpg
# Processed and saved: 239.jpg to C:\Users\Asus\Desktop\Pre\test\altar\239.jpg
# Processed and saved: 240.jpg to C:\Users\Asus\Desktop\Pre\test\altar\240.jpg
# Processed and saved: 241.jpg to C:\Users\Asus\Desktop\Pre\test\altar\241.jpg
# Processed and saved: 242.jpg to C:\Users\Asus\Desktop\Pre\test\altar\242.jpg
# Processed and saved: 243.jpg to C:\Users\Asus\Desktop\Pre\test\altar\243.jpg
# Processed and saved: 244.jpg to C:\Users\Asus\Desktop\Pre\test\altar\244.jpg
# Processed and saved: 245.jpg to C:\Users\Asus\Desktop\Pre\test\altar\245.jpg
# Processed and saved: 246.jpg to C:\Users\Asus\Desktop\Pre\test\altar\246.jpg
# Processed and saved: 247.jpg to C:\Users\Asus\Desktop\Pre\test\altar\247.jpg
# Processed and saved: 248.jpg to C:\Users\Asus\Desktop\Pre\test\altar\248.jpg
# Processed and saved: 249.jpg to C:\Users\Asus\Desktop\Pre\test\altar\249.jpg
# Processed and saved: 250.jpg to C:\Users\Asus\Desktop\Pre\test\altar\250.jpg
# Processed and saved: 251.jpg to C:\Users\Asus\Desktop\Pre\test\altar\251.jpg
# Processed and saved: 252.jpg to C:\Users\Asus\Desktop\Pre\test\altar\252.jpg
# Processed and saved: 253.jpg to C:\Users\Asus\Desktop\Pre\test\altar\253.jpg
# Processed and saved: 254.jpg to C:\Users\Asus\Desktop\Pre\test\altar\254.jpg
# Processed and saved: 255.jpg to C:\Users\Asus\Desktop\Pre\test\altar\255.jpg
# Processed and saved: 256.jpg to C:\Users\Asus\Desktop\Pre\test\altar\256.jpg
# Processed and saved: 257.jpg to C:\Users\Asus\Desktop\Pre\test\altar\257.jpg
# Processed and saved: 258.jpg to C:\Users\Asus\Desktop\Pre\test\altar\258.jpg
# Processed and saved: 259.jpg to C:\Users\Asus\Desktop\Pre\test\altar\259.jpg
# Processed and saved: 260.jpg to C:\Users\Asus\Desktop\Pre\test\altar\260.jpg
# Processed and saved: 261.jpg to C:\Users\Asus\Desktop\Pre\test\altar\261.jpg
# Processed and saved: 262.jpg to C:\Users\Asus\Desktop\Pre\test\altar\262.jpg
# Processed and saved: 263.jpg to C:\Users\Asus\Desktop\Pre\test\altar\263.jpg
# Processed and saved: 264.jpg to C:\Users\Asus\Desktop\Pre\test\altar\264.jpg
# Processed and saved: 265.jpg to C:\Users\Asus\Desktop\Pre\test\altar\265.jpg
# Processed and saved: 266.jpg to C:\Users\Asus\Desktop\Pre\test\altar\266.jpg
# Processed and saved: 267.jpg to C:\Users\Asus\Desktop\Pre\test\altar\267.jpg
# Processed and saved: 268.jpg to C:\Users\Asus\Desktop\Pre\test\altar\268.jpg
# Processed and saved: 269.jpg to C:\Users\Asus\Desktop\Pre\test\altar\269.jpg
# Processed and saved: 270.jpg to C:\Users\Asus\Desktop\Pre\test\altar\270.jpg
# Processed and saved: 271.jpg to C:\Users\Asus\Desktop\Pre\test\altar\271.jpg
# Processed and saved: 272.jpg to C:\Users\Asus\Desktop\Pre\test\altar\272.jpg
# Processed and saved: 273.jpg to C:\Users\Asus\Desktop\Pre\test\altar\273.jpg
# Processed and saved: 274.jpg to C:\Users\Asus\Desktop\Pre\test\altar\274.jpg
# Processed and saved: 275.jpg to C:\Users\Asus\Desktop\Pre\test\altar\275.jpg
# Processed and saved: 276.jpg to C:\Users\Asus\Desktop\Pre\test\altar\276.jpg
# Processed and saved: 277.jpg to C:\Users\Asus\Desktop\Pre\test\altar\277.jpg
# Processed and saved: 278.jpg to C:\Users\Asus\Desktop\Pre\test\altar\278.jpg
# Processed and saved: 279.jpg to C:\Users\Asus\Desktop\Pre\test\altar\279.jpg
# Processed and saved: 280.jpg to C:\Users\Asus\Desktop\Pre\test\altar\280.jpg
# Processed and saved: 281.jpg to C:\Users\Asus\Desktop\Pre\test\altar\281.jpg
# Processed and saved: 282.jpg to C:\Users\Asus\Desktop\Pre\test\altar\282.jpg
# Processed and saved: 283.jpg to C:\Users\Asus\Desktop\Pre\test\altar\283.jpg
# Processed and saved: 284.jpg to C:\Users\Asus\Desktop\Pre\test\altar\284.jpg
# Processed and saved: 285.jpg to C:\Users\Asus\Desktop\Pre\test\altar\285.jpg
# Processed and saved: 286.jpg to C:\Users\Asus\Desktop\Pre\test\altar\286.jpg
# Processed and saved: 287.jpg to C:\Users\Asus\Desktop\Pre\test\altar\287.jpg
# Processed and saved: 288.jpg to C:\Users\Asus\Desktop\Pre\test\altar\288.jpg
# Processed and saved: 289.jpg to C:\Users\Asus\Desktop\Pre\test\altar\289.jpg
# Processed and saved: 290.jpg to C:\Users\Asus\Desktop\Pre\test\altar\290.jpg
# Processed and saved: 291.jpg to C:\Users\Asus\Desktop\Pre\test\altar\291.jpg
# Processed and saved: 292.jpg to C:\Users\Asus\Desktop\Pre\test\altar\292.jpg
# Processed and saved: 293.jpg to C:\Users\Asus\Desktop\Pre\test\altar\293.jpg
# Processed and saved: 294.jpg to C:\Users\Asus\Desktop\Pre\test\altar\294.jpg
# Processed and saved: 295.jpg to C:\Users\Asus\Desktop\Pre\test\altar\295.jpg
# Processed and saved: 296.jpg to C:\Users\Asus\Desktop\Pre\test\altar\296.jpg
# Processed and saved: 297.jpg to C:\Users\Asus\Desktop\Pre\test\altar\297.jpg
# Processed and saved: 298.jpg to C:\Users\Asus\Desktop\Pre\test\altar\298.jpg
# Processed and saved: 299.jpg to C:\Users\Asus\Desktop\Pre\test\altar\299.jpg
# Processed and saved: 300.jpg to C:\Users\Asus\Desktop\Pre\test\altar\300.jpg
# Processed and saved: 301.jpg to C:\Users\Asus\Desktop\Pre\test\altar\301.jpg
# Processed and saved: 302.jpg to C:\Users\Asus\Desktop\Pre\test\altar\302.jpg
# Processed and saved: 303.jpg to C:\Users\Asus\Desktop\Pre\test\altar\303.jpg
# Processed and saved: 304.jpg to C:\Users\Asus\Desktop\Pre\test\altar\304.jpg
# Processed and saved: 305.jpg to C:\Users\Asus\Desktop\Pre\test\altar\305.jpg
# Processed and saved: 306.jpg to C:\Users\Asus\Desktop\Pre\test\altar\306.jpg
# Processed and saved: 307.jpg to C:\Users\Asus\Desktop\Pre\test\altar\307.jpg
# Processed and saved: 308.jpg to C:\Users\Asus\Desktop\Pre\test\altar\308.jpg
# Processed and saved: 309.jpg to C:\Users\Asus\Desktop\Pre\test\altar\309.jpg
# Processed and saved: 310.jpg to C:\Users\Asus\Desktop\Pre\test\altar\310.jpg
# Processed and saved: 311.jpg to C:\Users\Asus\Desktop\Pre\test\altar\311.jpg
# Processed and saved: 312.jpg to C:\Users\Asus\Desktop\Pre\test\altar\312.jpg
# Processed and saved: 313.jpg to C:\Users\Asus\Desktop\Pre\test\altar\313.jpg
# Processed and saved: 314.jpg to C:\Users\Asus\Desktop\Pre\test\altar\314.jpg
# Processed and saved: 315.jpg to C:\Users\Asus\Desktop\Pre\test\altar\315.jpg
# Processed and saved: 316.jpg to C:\Users\Asus\Desktop\Pre\test\altar\316.jpg
# Processed and saved: 317.jpg to C:\Users\Asus\Desktop\Pre\test\altar\317.jpg
# Processed and saved: 318.jpg to C:\Users\Asus\Desktop\Pre\test\altar\318.jpg
# Processed and saved: 319.jpg to C:\Users\Asus\Desktop\Pre\test\altar\319.jpg
# Processed and saved: 320.jpg to C:\Users\Asus\Desktop\Pre\test\altar\320.jpg
# Processed and saved: 321.jpg to C:\Users\Asus\Desktop\Pre\test\altar\321.jpg
# Processed and saved: 322.jpg to C:\Users\Asus\Desktop\Pre\test\altar\322.jpg
# Processed and saved: 323.jpg to C:\Users\Asus\Desktop\Pre\test\altar\323.jpg
# Processed and saved: 324.jpg to C:\Users\Asus\Desktop\Pre\test\altar\324.jpg
# Processed and saved: 325.jpg to C:\Users\Asus\Desktop\Pre\test\altar\325.jpg
# Processed and saved: 326.jpg to C:\Users\Asus\Desktop\Pre\test\altar\326.jpg
# Processed and saved: 327.jpg to C:\Users\Asus\Desktop\Pre\test\altar\327.jpg
# Processed and saved: 328.jpg to C:\Users\Asus\Desktop\Pre\test\altar\328.jpg
# Processed and saved: 329.jpg to C:\Users\Asus\Desktop\Pre\test\altar\329.jpg
# Processed and saved: 330.jpg to C:\Users\Asus\Desktop\Pre\test\altar\330.jpg
# Processed and saved: 331.jpg to C:\Users\Asus\Desktop\Pre\test\altar\331.jpg
# Processed and saved: 332.jpg to C:\Users\Asus\Desktop\Pre\test\altar\332.jpg
# Processed and saved: 333.jpg to C:\Users\Asus\Desktop\Pre\test\altar\333.jpg
# Processed and saved: 334.jpg to C:\Users\Asus\Desktop\Pre\test\altar\334.jpg
# Processed and saved: 335.jpg to C:\Users\Asus\Desktop\Pre\test\altar\335.jpg
# Processed and saved: 336.jpg to C:\Users\Asus\Desktop\Pre\test\altar\336.jpg
# Processed and saved: 337.jpg to C:\Users\Asus\Desktop\Pre\test\altar\337.jpg
# Processed and saved: 338.jpg to C:\Users\Asus\Desktop\Pre\test\altar\338.jpg
# Processed and saved: 339.jpg to C:\Users\Asus\Desktop\Pre\test\altar\339.jpg
# Processed and saved: 340.jpg to C:\Users\Asus\Desktop\Pre\test\altar\340.jpg
# Processed and saved: 341.jpg to C:\Users\Asus\Desktop\Pre\test\altar\341.jpg
# Processed and saved: 342.jpg to C:\Users\Asus\Desktop\Pre\test\altar\342.jpg
# Processed and saved: 343.jpg to C:\Users\Asus\Desktop\Pre\test\altar\343.jpg
# Processed and saved: 344.jpg to C:\Users\Asus\Desktop\Pre\test\altar\344.jpg
# Processed and saved: 345.jpg to C:\Users\Asus\Desktop\Pre\test\altar\345.jpg
# Processed and saved: 346.jpg to C:\Users\Asus\Desktop\Pre\test\altar\346.jpg
# Processed and saved: 347.jpg to C:\Users\Asus\Desktop\Pre\test\altar\347.jpg
# Processed and saved: 348.jpg to C:\Users\Asus\Desktop\Pre\test\altar\348.jpg
# Processed and saved: 349.jpg to C:\Users\Asus\Desktop\Pre\test\altar\349.jpg
# Processed and saved: 350.jpg to C:\Users\Asus\Desktop\Pre\test\altar\350.jpg
# Processed and saved: 351.jpg to C:\Users\Asus\Desktop\Pre\test\altar\351.jpg
# Processed and saved: 352.jpg to C:\Users\Asus\Desktop\Pre\test\altar\352.jpg
# Processed and saved: 353.jpg to C:\Users\Asus\Desktop\Pre\test\altar\353.jpg
# Processed and saved: 354.jpg to C:\Users\Asus\Desktop\Pre\test\altar\354.jpg
# Processed and saved: 355.jpg to C:\Users\Asus\Desktop\Pre\test\altar\355.jpg
# Processed and saved: 356.jpg to C:\Users\Asus\Desktop\Pre\test\altar\356.jpg
# Processed and saved: 357.jpg to C:\Users\Asus\Desktop\Pre\test\altar\357.jpg
# Processed and saved: 358.jpg to C:\Users\Asus\Desktop\Pre\test\altar\358.jpg
# Processed and saved: 359.jpg to C:\Users\Asus\Desktop\Pre\test\altar\359.jpg
# Processed and saved: 944.jpg to C:\Users\Asus\Desktop\Pre\test\apse\944.jpg
# Processed and saved: 945.jpg to C:\Users\Asus\Desktop\Pre\test\apse\945.jpg
# Processed and saved: 946.jpg to C:\Users\Asus\Desktop\Pre\test\apse\946.jpg
# Processed and saved: 947.jpg to C:\Users\Asus\Desktop\Pre\test\apse\947.jpg
# Processed and saved: 948.jpg to C:\Users\Asus\Desktop\Pre\test\apse\948.jpg
# Processed and saved: 949.jpg to C:\Users\Asus\Desktop\Pre\test\apse\949.jpg
# Processed and saved: 950.jpg to C:\Users\Asus\Desktop\Pre\test\apse\950.jpg
# Processed and saved: 951.jpg to C:\Users\Asus\Desktop\Pre\test\apse\951.jpg
# Processed and saved: 952.jpg to C:\Users\Asus\Desktop\Pre\test\apse\952.jpg
# Processed and saved: 953.jpg to C:\Users\Asus\Desktop\Pre\test\apse\953.jpg
# Processed and saved: 954.jpg to C:\Users\Asus\Desktop\Pre\test\apse\954.jpg
# Processed and saved: 955.jpg to C:\Users\Asus\Desktop\Pre\test\apse\955.jpg
# Processed and saved: 956.jpg to C:\Users\Asus\Desktop\Pre\test\apse\956.jpg
# Processed and saved: 957.jpg to C:\Users\Asus\Desktop\Pre\test\apse\957.jpg
# Processed and saved: 958.jpg to C:\Users\Asus\Desktop\Pre\test\apse\958.jpg
# Processed and saved: 959.jpg to C:\Users\Asus\Desktop\Pre\test\apse\959.jpg
# Processed and saved: 960.jpg to C:\Users\Asus\Desktop\Pre\test\apse\960.jpg
# Processed and saved: 961.jpg to C:\Users\Asus\Desktop\Pre\test\apse\961.jpg
# Processed and saved: 962.jpg to C:\Users\Asus\Desktop\Pre\test\apse\962.jpg
# Processed and saved: 963.jpg to C:\Users\Asus\Desktop\Pre\test\apse\963.jpg
# Processed and saved: 964.jpg to C:\Users\Asus\Desktop\Pre\test\apse\964.jpg
# Processed and saved: 965.jpg to C:\Users\Asus\Desktop\Pre\test\apse\965.jpg
# Processed and saved: 966.jpg to C:\Users\Asus\Desktop\Pre\test\apse\966.jpg
# Processed and saved: 967.jpg to C:\Users\Asus\Desktop\Pre\test\apse\967.jpg
# Processed and saved: 968.jpg to C:\Users\Asus\Desktop\Pre\test\apse\968.jpg
# Processed and saved: 969.jpg to C:\Users\Asus\Desktop\Pre\test\apse\969.jpg
# Processed and saved: 970.jpg to C:\Users\Asus\Desktop\Pre\test\apse\970.jpg
# Processed and saved: 971.jpg to C:\Users\Asus\Desktop\Pre\test\apse\971.jpg
# Processed and saved: 972.jpg to C:\Users\Asus\Desktop\Pre\test\apse\972.jpg
# Processed and saved: 973.jpg to C:\Users\Asus\Desktop\Pre\test\apse\973.jpg
# Processed and saved: 974.jpg to C:\Users\Asus\Desktop\Pre\test\apse\974.jpg
# Processed and saved: 975.jpg to C:\Users\Asus\Desktop\Pre\test\apse\975.jpg
# Processed and saved: 976.jpg to C:\Users\Asus\Desktop\Pre\test\apse\976.jpg
# Processed and saved: 977.jpg to C:\Users\Asus\Desktop\Pre\test\apse\977.jpg
# Processed and saved: 978.jpg to C:\Users\Asus\Desktop\Pre\test\apse\978.jpg
# Processed and saved: 979.jpg to C:\Users\Asus\Desktop\Pre\test\apse\979.jpg
# Processed and saved: 980.jpg to C:\Users\Asus\Desktop\Pre\test\apse\980.jpg
# Processed and saved: 981.jpg to C:\Users\Asus\Desktop\Pre\test\apse\981.jpg
# Processed and saved: 982.jpg to C:\Users\Asus\Desktop\Pre\test\apse\982.jpg
# Processed and saved: 983.jpg to C:\Users\Asus\Desktop\Pre\test\apse\983.jpg
# Processed and saved: 984.jpg to C:\Users\Asus\Desktop\Pre\test\apse\984.jpg
# Processed and saved: 985.jpg to C:\Users\Asus\Desktop\Pre\test\apse\985.jpg
# Processed and saved: 986.jpg to C:\Users\Asus\Desktop\Pre\test\apse\986.jpg
# Processed and saved: 987.jpg to C:\Users\Asus\Desktop\Pre\test\apse\987.jpg
# Processed and saved: 988.jpg to C:\Users\Asus\Desktop\Pre\test\apse\988.jpg
# Processed and saved: 989.jpg to C:\Users\Asus\Desktop\Pre\test\apse\989.jpg
# Processed and saved: 990.jpg to C:\Users\Asus\Desktop\Pre\test\apse\990.jpg
# Processed and saved: 991.jpg to C:\Users\Asus\Desktop\Pre\test\apse\991.jpg
# Processed and saved: 992.jpg to C:\Users\Asus\Desktop\Pre\test\apse\992.jpg
# Processed and saved: 993.jpg to C:\Users\Asus\Desktop\Pre\test\apse\993.jpg
# Processed and saved: 1234.jpg to C:\Users\Asus\Desktop\Pre\test\bell_tower\1234.jpg
# Processed and saved: 1235.jpg to C:\Users\Asus\Desktop\Pre\test\bell_tower\1235.jpg
# Processed and saved: 1236.jpg to C:\Users\Asus\Desktop\Pre\test\bell_tower\1236.jpg
# Processed and saved: 1237.jpg to C:\Users\Asus\Desktop\Pre\test\bell_tower\1237.jpg
# Processed and saved: 1238.jpg to C:\Users\Asus\Desktop\Pre\test\bell_tower\1238.jpg
# Processed and saved: 1239.jpg to C:\Users\Asus\Desktop\Pre\test\bell_tower\1239.jpg
# Processed and saved: 1240.jpg to C:\Users\Asus\Desktop\Pre\test\bell_tower\1240.jpg
# Processed and saved: 1241.jpg to C:\Users\Asus\Desktop\Pre\test\bell_tower\1241.jpg
# Processed and saved: 1242.jpg to C:\Users\Asus\Desktop\Pre\test\bell_tower\1242.jpg
# Processed and saved: 1243.jpg to C:\Users\Asus\Desktop\Pre\test\bell_tower\1243.jpg
# Processed and saved: 1244.jpg to C:\Users\Asus\Desktop\Pre\test\bell_tower\1244.jpg
# Processed and saved: 1245.jpg to C:\Users\Asus\Desktop\Pre\test\bell_tower\1245.jpg
# Processed and saved: 1246.jpg to C:\Users\Asus\Desktop\Pre\test\bell_tower\1246.jpg
# Processed and saved: 1247.jpg to C:\Users\Asus\Desktop\Pre\test\bell_tower\1247.jpg
# Processed and saved: 1248.jpg to C:\Users\Asus\Desktop\Pre\test\bell_tower\1248.jpg
# Processed and saved: 1249.jpg to C:\Users\Asus\Desktop\Pre\test\bell_tower\1249.jpg
# Processed and saved: 1250.jpg to C:\Users\Asus\Desktop\Pre\test\bell_tower\1250.jpg
# Processed and saved: 1251.jpg to C:\Users\Asus\Desktop\Pre\test\bell_tower\1251.jpg
# Processed and saved: 1252.jpg to C:\Users\Asus\Desktop\Pre\test\bell_tower\1252.jpg
# Processed and saved: 1253.jpg to C:\Users\Asus\Desktop\Pre\test\bell_tower\1253.jpg
# Processed and saved: 1254.jpg to C:\Users\Asus\Desktop\Pre\test\bell_tower\1254.jpg
# Processed and saved: 1255.jpg to C:\Users\Asus\Desktop\Pre\test\bell_tower\1255.jpg
# Processed and saved: 1256.jpg to C:\Users\Asus\Desktop\Pre\test\bell_tower\1256.jpg
# Processed and saved: 1257.jpg to C:\Users\Asus\Desktop\Pre\test\bell_tower\1257.jpg
# Processed and saved: 1258.jpg to C:\Users\Asus\Desktop\Pre\test\bell_tower\1258.jpg
# Processed and saved: 1259.jpg to C:\Users\Asus\Desktop\Pre\test\bell_tower\1259.jpg
# Processed and saved: 1260.jpg to C:\Users\Asus\Desktop\Pre\test\bell_tower\1260.jpg
# Processed and saved: 1261.jpg to C:\Users\Asus\Desktop\Pre\test\bell_tower\1261.jpg
# Processed and saved: 1262.jpg to C:\Users\Asus\Desktop\Pre\test\bell_tower\1262.jpg
# Processed and saved: 1263.jpg to C:\Users\Asus\Desktop\Pre\test\bell_tower\1263.jpg
# Processed and saved: 1264.jpg to C:\Users\Asus\Desktop\Pre\test\bell_tower\1264.jpg
# Processed and saved: 1265.jpg to C:\Users\Asus\Desktop\Pre\test\bell_tower\1265.jpg
# Processed and saved: 1266.jpg to C:\Users\Asus\Desktop\Pre\test\bell_tower\1266.jpg
# Processed and saved: 1267.jpg to C:\Users\Asus\Desktop\Pre\test\bell_tower\1267.jpg
# Processed and saved: 1268.jpg to C:\Users\Asus\Desktop\Pre\test\bell_tower\1268.jpg
# Processed and saved: 1269.jpg to C:\Users\Asus\Desktop\Pre\test\bell_tower\1269.jpg
# Processed and saved: 1270.jpg to C:\Users\Asus\Desktop\Pre\test\bell_tower\1270.jpg
# Processed and saved: 1271.jpg to C:\Users\Asus\Desktop\Pre\test\bell_tower\1271.jpg
# Processed and saved: 1272.jpg to C:\Users\Asus\Desktop\Pre\test\bell_tower\1272.jpg
# Processed and saved: 1273.jpg to C:\Users\Asus\Desktop\Pre\test\bell_tower\1273.jpg
# Processed and saved: 1274.jpg to C:\Users\Asus\Desktop\Pre\test\bell_tower\1274.jpg
# Processed and saved: 1275.jpg to C:\Users\Asus\Desktop\Pre\test\bell_tower\1275.jpg
# Processed and saved: 1276.jpg to C:\Users\Asus\Desktop\Pre\test\bell_tower\1276.jpg
# Processed and saved: 1277.jpg to C:\Users\Asus\Desktop\Pre\test\bell_tower\1277.jpg
# Processed and saved: 1278.jpg to C:\Users\Asus\Desktop\Pre\test\bell_tower\1278.jpg
# Processed and saved: 1279.jpg to C:\Users\Asus\Desktop\Pre\test\bell_tower\1279.jpg
# Processed and saved: 1280.jpg to C:\Users\Asus\Desktop\Pre\test\bell_tower\1280.jpg
# Processed and saved: 1281.jpg to C:\Users\Asus\Desktop\Pre\test\bell_tower\1281.jpg
# Processed and saved: 1282.jpg to C:\Users\Asus\Desktop\Pre\test\bell_tower\1282.jpg
# Processed and saved: 1283.jpg to C:\Users\Asus\Desktop\Pre\test\bell_tower\1283.jpg
# Processed and saved: 1284.jpg to C:\Users\Asus\Desktop\Pre\test\bell_tower\1284.jpg
# Processed and saved: 1285.jpg to C:\Users\Asus\Desktop\Pre\test\bell_tower\1285.jpg
# Processed and saved: 1286.jpg to C:\Users\Asus\Desktop\Pre\test\bell_tower\1286.jpg
# Processed and saved: 1287.jpg to C:\Users\Asus\Desktop\Pre\test\bell_tower\1287.jpg
# Processed and saved: 1288.jpg to C:\Users\Asus\Desktop\Pre\test\bell_tower\1288.jpg
# Processed and saved: 1289.jpg to C:\Users\Asus\Desktop\Pre\test\bell_tower\1289.jpg
# Processed and saved: 1290.jpg to C:\Users\Asus\Desktop\Pre\test\bell_tower\1290.jpg
# Processed and saved: 1291.jpg to C:\Users\Asus\Desktop\Pre\test\bell_tower\1291.jpg
# Processed and saved: 1292.jpg to C:\Users\Asus\Desktop\Pre\test\bell_tower\1292.jpg
# Processed and saved: 1293.jpg to C:\Users\Asus\Desktop\Pre\test\bell_tower\1293.jpg
# Processed and saved: 1294.jpg to C:\Users\Asus\Desktop\Pre\test\bell_tower\1294.jpg
# Processed and saved: 1295.jpg to C:\Users\Asus\Desktop\Pre\test\bell_tower\1295.jpg
# Processed and saved: 1296.jpg to C:\Users\Asus\Desktop\Pre\test\bell_tower\1296.jpg
# Processed and saved: 1297.jpg to C:\Users\Asus\Desktop\Pre\test\bell_tower\1297.jpg
# Processed and saved: 1298.jpg to C:\Users\Asus\Desktop\Pre\test\bell_tower\1298.jpg
# Processed and saved: 1299.jpg to C:\Users\Asus\Desktop\Pre\test\bell_tower\1299.jpg
# Processed and saved: 1300.jpg to C:\Users\Asus\Desktop\Pre\test\bell_tower\1300.jpg
# Processed and saved: 1301.jpg to C:\Users\Asus\Desktop\Pre\test\bell_tower\1301.jpg
# Processed and saved: 1302.jpg to C:\Users\Asus\Desktop\Pre\test\bell_tower\1302.jpg
# Processed and saved: 1303.jpg to C:\Users\Asus\Desktop\Pre\test\bell_tower\1303.jpg
# Processed and saved: 1304.jpg to C:\Users\Asus\Desktop\Pre\test\bell_tower\1304.jpg
# Processed and saved: 1305.jpg to C:\Users\Asus\Desktop\Pre\test\bell_tower\1305.jpg
# Processed and saved: 1306.jpg to C:\Users\Asus\Desktop\Pre\test\bell_tower\1306.jpg
# Processed and saved: 1307.jpg to C:\Users\Asus\Desktop\Pre\test\bell_tower\1307.jpg
# Processed and saved: 1308.jpg to C:\Users\Asus\Desktop\Pre\test\bell_tower\1308.jpg
# Processed and saved: 1309.jpg to C:\Users\Asus\Desktop\Pre\test\bell_tower\1309.jpg
# Processed and saved: 1310.jpg to C:\Users\Asus\Desktop\Pre\test\bell_tower\1310.jpg
# Processed and saved: 1311.jpg to C:\Users\Asus\Desktop\Pre\test\bell_tower\1311.jpg
# Processed and saved: 1312.jpg to C:\Users\Asus\Desktop\Pre\test\bell_tower\1312.jpg
# Processed and saved: 1313.jpg to C:\Users\Asus\Desktop\Pre\test\bell_tower\1313.jpg
# Processed and saved: 1314.jpg to C:\Users\Asus\Desktop\Pre\test\bell_tower\1314.jpg
# Processed and saved: 1315.jpg to C:\Users\Asus\Desktop\Pre\test\bell_tower\1315.jpg
# Processed and saved: 1316.jpg to C:\Users\Asus\Desktop\Pre\test\bell_tower\1316.jpg
# Processed and saved: 1317.jpg to C:\Users\Asus\Desktop\Pre\test\bell_tower\1317.jpg
# Processed and saved: 1318.jpg to C:\Users\Asus\Desktop\Pre\test\bell_tower\1318.jpg
# Processed and saved: 1319.jpg to C:\Users\Asus\Desktop\Pre\test\bell_tower\1319.jpg
# Processed and saved: 1320.jpg to C:\Users\Asus\Desktop\Pre\test\bell_tower\1320.jpg
# Processed and saved: 1321.jpg to C:\Users\Asus\Desktop\Pre\test\bell_tower\1321.jpg
# Processed and saved: 1322.jpg to C:\Users\Asus\Desktop\Pre\test\bell_tower\1322.jpg
# Processed and saved: 1323.jpg to C:\Users\Asus\Desktop\Pre\test\bell_tower\1323.jpg
# Processed and saved: 1324.jpg to C:\Users\Asus\Desktop\Pre\test\bell_tower\1324.jpg
# Processed and saved: 1325.jpg to C:\Users\Asus\Desktop\Pre\test\bell_tower\1325.jpg
# Processed and saved: 1326.jpg to C:\Users\Asus\Desktop\Pre\test\bell_tower\1326.jpg
# Processed and saved: 1327.jpg to C:\Users\Asus\Desktop\Pre\test\bell_tower\1327.jpg
# Processed and saved: 1328.jpg to C:\Users\Asus\Desktop\Pre\test\bell_tower\1328.jpg
# Processed and saved: 1329.jpg to C:\Users\Asus\Desktop\Pre\test\bell_tower\1329.jpg
# Processed and saved: 1330.jpg to C:\Users\Asus\Desktop\Pre\test\bell_tower\1330.jpg
# Processed and saved: 1331.jpg to C:\Users\Asus\Desktop\Pre\test\bell_tower\1331.jpg
# Processed and saved: 1332.jpg to C:\Users\Asus\Desktop\Pre\test\bell_tower\1332.jpg
# Processed and saved: 1333.jpg to C:\Users\Asus\Desktop\Pre\test\bell_tower\1333.jpg
# Processed and saved: 1334.jpg to C:\Users\Asus\Desktop\Pre\test\bell_tower\1334.jpg
# Processed and saved: 1335.jpg to C:\Users\Asus\Desktop\Pre\test\bell_tower\1335.jpg
# Processed and saved: 1336.jpg to C:\Users\Asus\Desktop\Pre\test\bell_tower\1336.jpg
# Processed and saved: 1337.jpg to C:\Users\Asus\Desktop\Pre\test\bell_tower\1337.jpg
# Processed and saved: 1338.jpg to C:\Users\Asus\Desktop\Pre\test\bell_tower\1338.jpg
# Processed and saved: 1339.jpg to C:\Users\Asus\Desktop\Pre\test\bell_tower\1339.jpg
# Processed and saved: 1340.jpg to C:\Users\Asus\Desktop\Pre\test\bell_tower\1340.jpg
# Processed and saved: 1341.jpg to C:\Users\Asus\Desktop\Pre\test\bell_tower\1341.jpg
# Processed and saved: 1342.jpg to C:\Users\Asus\Desktop\Pre\test\bell_tower\1342.jpg
# Processed and saved: 1343.jpg to C:\Users\Asus\Desktop\Pre\test\bell_tower\1343.jpg
# Processed and saved: 1344.jpg to C:\Users\Asus\Desktop\Pre\test\bell_tower\1344.jpg
# Processed and saved: 1345.jpg to C:\Users\Asus\Desktop\Pre\test\bell_tower\1345.jpg
# Processed and saved: 1346.jpg to C:\Users\Asus\Desktop\Pre\test\bell_tower\1346.jpg
# Processed and saved: 1347.jpg to C:\Users\Asus\Desktop\Pre\test\bell_tower\1347.jpg
# Processed and saved: 1348.jpg to C:\Users\Asus\Desktop\Pre\test\bell_tower\1348.jpg
# Processed and saved: 1349.jpg to C:\Users\Asus\Desktop\Pre\test\bell_tower\1349.jpg
# Processed and saved: 1350.jpg to C:\Users\Asus\Desktop\Pre\test\bell_tower\1350.jpg
# Processed and saved: 1351.jpg to C:\Users\Asus\Desktop\Pre\test\bell_tower\1351.jpg
# Processed and saved: 1352.jpg to C:\Users\Asus\Desktop\Pre\test\bell_tower\1352.jpg
# Processed and saved: 1353.jpg to C:\Users\Asus\Desktop\Pre\test\bell_tower\1353.jpg
# Processed and saved: 1354.jpg to C:\Users\Asus\Desktop\Pre\test\bell_tower\1354.jpg
# Processed and saved: 1355.jpg to C:\Users\Asus\Desktop\Pre\test\bell_tower\1355.jpg
# Processed and saved: 1356.jpg to C:\Users\Asus\Desktop\Pre\test\bell_tower\1356.jpg
# Processed and saved: 1357.jpg to C:\Users\Asus\Desktop\Pre\test\bell_tower\1357.jpg
# Processed and saved: 1358.jpg to C:\Users\Asus\Desktop\Pre\test\bell_tower\1358.jpg
# Processed and saved: 1359.jpg to C:\Users\Asus\Desktop\Pre\test\bell_tower\1359.jpg
# Processed and saved: 1360.jpg to C:\Users\Asus\Desktop\Pre\test\bell_tower\1360.jpg
# Processed and saved: 1361.jpg to C:\Users\Asus\Desktop\Pre\test\bell_tower\1361.jpg
# Processed and saved: 1362.jpg to C:\Users\Asus\Desktop\Pre\test\bell_tower\1362.jpg
# Processed and saved: 1363.jpg to C:\Users\Asus\Desktop\Pre\test\bell_tower\1363.jpg
# Processed and saved: 1364.jpg to C:\Users\Asus\Desktop\Pre\test\bell_tower\1364.jpg
# Processed and saved: 1365.jpg to C:\Users\Asus\Desktop\Pre\test\bell_tower\1365.jpg
# Processed and saved: 1366.jpg to C:\Users\Asus\Desktop\Pre\test\bell_tower\1366.jpg
# Processed and saved: 1367.jpg to C:\Users\Asus\Desktop\Pre\test\bell_tower\1367.jpg
# Processed and saved: 1368.jpg to C:\Users\Asus\Desktop\Pre\test\bell_tower\1368.jpg
# Processed and saved: 1369.jpg to C:\Users\Asus\Desktop\Pre\test\bell_tower\1369.jpg
# Processed and saved: 1370.jpg to C:\Users\Asus\Desktop\Pre\test\bell_tower\1370.jpg
# Processed and saved: 1371.jpg to C:\Users\Asus\Desktop\Pre\test\bell_tower\1371.jpg
# Processed and saved: 1372.jpg to C:\Users\Asus\Desktop\Pre\test\bell_tower\1372.jpg
# Processed and saved: 1373.jpg to C:\Users\Asus\Desktop\Pre\test\bell_tower\1373.jpg
# Processed and saved: 1374.jpg to C:\Users\Asus\Desktop\Pre\test\bell_tower\1374.jpg
# Processed and saved: 1375.jpg to C:\Users\Asus\Desktop\Pre\test\bell_tower\1375.jpg
# Processed and saved: 1376.jpg to C:\Users\Asus\Desktop\Pre\test\bell_tower\1376.jpg
# Processed and saved: 1377.jpg to C:\Users\Asus\Desktop\Pre\test\bell_tower\1377.jpg
# Processed and saved: 1378.jpg to C:\Users\Asus\Desktop\Pre\test\bell_tower\1378.jpg
# Processed and saved: 1379.jpg to C:\Users\Asus\Desktop\Pre\test\bell_tower\1379.jpg
# Processed and saved: 1380.jpg to C:\Users\Asus\Desktop\Pre\test\bell_tower\1380.jpg
# Processed and saved: 1381.jpg to C:\Users\Asus\Desktop\Pre\test\bell_tower\1381.jpg
# Processed and saved: 1382.jpg to C:\Users\Asus\Desktop\Pre\test\bell_tower\1382.jpg
# Processed and saved: 1383.jpg to C:\Users\Asus\Desktop\Pre\test\bell_tower\1383.jpg
# Processed and saved: 1384.jpg to C:\Users\Asus\Desktop\Pre\test\bell_tower\1384.jpg
# Processed and saved: 1385.jpg to C:\Users\Asus\Desktop\Pre\test\bell_tower\1385.jpg
# Processed and saved: 1386.jpg to C:\Users\Asus\Desktop\Pre\test\bell_tower\1386.jpg
# Processed and saved: 1387.jpg to C:\Users\Asus\Desktop\Pre\test\bell_tower\1387.jpg
# Processed and saved: 1388.jpg to C:\Users\Asus\Desktop\Pre\test\bell_tower\1388.jpg
# Processed and saved: 1389.jpg to C:\Users\Asus\Desktop\Pre\test\bell_tower\1389.jpg
# Processed and saved: 1390.jpg to C:\Users\Asus\Desktop\Pre\test\bell_tower\1390.jpg
# Processed and saved: 1391.jpg to C:\Users\Asus\Desktop\Pre\test\bell_tower\1391.jpg
# Processed and saved: 1392.jpg to C:\Users\Asus\Desktop\Pre\test\bell_tower\1392.jpg
# Processed and saved: 1393.jpg to C:\Users\Asus\Desktop\Pre\test\bell_tower\1393.jpg
# Processed and saved: 1394.jpg to C:\Users\Asus\Desktop\Pre\test\bell_tower\1394.jpg
# Processed and saved: 1395.jpg to C:\Users\Asus\Desktop\Pre\test\bell_tower\1395.jpg
# Processed and saved: 1396.jpg to C:\Users\Asus\Desktop\Pre\test\bell_tower\1396.jpg
# Processed and saved: 1397.jpg to C:\Users\Asus\Desktop\Pre\test\bell_tower\1397.jpg
# Processed and saved: 1398.jpg to C:\Users\Asus\Desktop\Pre\test\bell_tower\1398.jpg
# Processed and saved: 1399.jpg to C:\Users\Asus\Desktop\Pre\test\bell_tower\1399.jpg
# Processed and saved: 1400.jpg to C:\Users\Asus\Desktop\Pre\test\bell_tower\1400.jpg
# Processed and saved: 1401.jpg to C:\Users\Asus\Desktop\Pre\test\bell_tower\1401.jpg
# Processed and saved: 1402.jpg to C:\Users\Asus\Desktop\Pre\test\bell_tower\1402.jpg
# Processed and saved: 1403.jpg to C:\Users\Asus\Desktop\Pre\test\bell_tower\1403.jpg
# Processed and saved: 360.jpg to C:\Users\Asus\Desktop\Pre\test\column\360.jpg
# Processed and saved: 361.jpg to C:\Users\Asus\Desktop\Pre\test\column\361.jpg
# Processed and saved: 362.jpg to C:\Users\Asus\Desktop\Pre\test\column\362.jpg
# Processed and saved: 363.jpg to C:\Users\Asus\Desktop\Pre\test\column\363.jpg
# Processed and saved: 364.jpg to C:\Users\Asus\Desktop\Pre\test\column\364.jpg
# Processed and saved: 365.jpg to C:\Users\Asus\Desktop\Pre\test\column\365.jpg
# Processed and saved: 366.jpg to C:\Users\Asus\Desktop\Pre\test\column\366.jpg
# Processed and saved: 367.jpg to C:\Users\Asus\Desktop\Pre\test\column\367.jpg
# Processed and saved: 368.jpg to C:\Users\Asus\Desktop\Pre\test\column\368.jpg
# Processed and saved: 369.jpg to C:\Users\Asus\Desktop\Pre\test\column\369.jpg
# Processed and saved: 370.jpg to C:\Users\Asus\Desktop\Pre\test\column\370.jpg
# Processed and saved: 371.jpg to C:\Users\Asus\Desktop\Pre\test\column\371.jpg
# Processed and saved: 372.jpg to C:\Users\Asus\Desktop\Pre\test\column\372.jpg
# Processed and saved: 373.jpg to C:\Users\Asus\Desktop\Pre\test\column\373.jpg
# Processed and saved: 374.jpg to C:\Users\Asus\Desktop\Pre\test\column\374.jpg
# Processed and saved: 375.jpg to C:\Users\Asus\Desktop\Pre\test\column\375.jpg
# Processed and saved: 376.jpg to C:\Users\Asus\Desktop\Pre\test\column\376.jpg
# Processed and saved: 377.jpg to C:\Users\Asus\Desktop\Pre\test\column\377.jpg
# Processed and saved: 378.jpg to C:\Users\Asus\Desktop\Pre\test\column\378.jpg
# Processed and saved: 379.jpg to C:\Users\Asus\Desktop\Pre\test\column\379.jpg
# Processed and saved: 380.jpg to C:\Users\Asus\Desktop\Pre\test\column\380.jpg
# Processed and saved: 381.jpg to C:\Users\Asus\Desktop\Pre\test\column\381.jpg
# Processed and saved: 382.jpg to C:\Users\Asus\Desktop\Pre\test\column\382.jpg
# Processed and saved: 383.jpg to C:\Users\Asus\Desktop\Pre\test\column\383.jpg
# Processed and saved: 384.jpg to C:\Users\Asus\Desktop\Pre\test\column\384.jpg
# Processed and saved: 385.jpg to C:\Users\Asus\Desktop\Pre\test\column\385.jpg
# Processed and saved: 386.jpg to C:\Users\Asus\Desktop\Pre\test\column\386.jpg
# Processed and saved: 387.jpg to C:\Users\Asus\Desktop\Pre\test\column\387.jpg
# Processed and saved: 388.jpg to C:\Users\Asus\Desktop\Pre\test\column\388.jpg
# Processed and saved: 389.jpg to C:\Users\Asus\Desktop\Pre\test\column\389.jpg
# Processed and saved: 390.jpg to C:\Users\Asus\Desktop\Pre\test\column\390.jpg
# Processed and saved: 391.jpg to C:\Users\Asus\Desktop\Pre\test\column\391.jpg
# Processed and saved: 392.jpg to C:\Users\Asus\Desktop\Pre\test\column\392.jpg
# Processed and saved: 393.jpg to C:\Users\Asus\Desktop\Pre\test\column\393.jpg
# Processed and saved: 394.jpg to C:\Users\Asus\Desktop\Pre\test\column\394.jpg
# Processed and saved: 395.jpg to C:\Users\Asus\Desktop\Pre\test\column\395.jpg
# Processed and saved: 396.jpg to C:\Users\Asus\Desktop\Pre\test\column\396.jpg
# Processed and saved: 397.jpg to C:\Users\Asus\Desktop\Pre\test\column\397.jpg
# Processed and saved: 398.jpg to C:\Users\Asus\Desktop\Pre\test\column\398.jpg
# Processed and saved: 399.jpg to C:\Users\Asus\Desktop\Pre\test\column\399.jpg
# Processed and saved: 400.jpg to C:\Users\Asus\Desktop\Pre\test\column\400.jpg
# Processed and saved: 401.jpg to C:\Users\Asus\Desktop\Pre\test\column\401.jpg
# Processed and saved: 402.jpg to C:\Users\Asus\Desktop\Pre\test\column\402.jpg
# Processed and saved: 403.jpg to C:\Users\Asus\Desktop\Pre\test\column\403.jpg
# Processed and saved: 404.jpg to C:\Users\Asus\Desktop\Pre\test\column\404.jpg
# Processed and saved: 405.jpg to C:\Users\Asus\Desktop\Pre\test\column\405.jpg
# Processed and saved: 406.jpg to C:\Users\Asus\Desktop\Pre\test\column\406.jpg
# Processed and saved: 407.jpg to C:\Users\Asus\Desktop\Pre\test\column\407.jpg
# Processed and saved: 408.jpg to C:\Users\Asus\Desktop\Pre\test\column\408.jpg
# Processed and saved: 409.jpg to C:\Users\Asus\Desktop\Pre\test\column\409.jpg
# Processed and saved: 410.jpg to C:\Users\Asus\Desktop\Pre\test\column\410.jpg
# Processed and saved: 411.jpg to C:\Users\Asus\Desktop\Pre\test\column\411.jpg
# Processed and saved: 412.jpg to C:\Users\Asus\Desktop\Pre\test\column\412.jpg
# Processed and saved: 413.jpg to C:\Users\Asus\Desktop\Pre\test\column\413.jpg
# Processed and saved: 414.jpg to C:\Users\Asus\Desktop\Pre\test\column\414.jpg
# Processed and saved: 415.jpg to C:\Users\Asus\Desktop\Pre\test\column\415.jpg
# Processed and saved: 416.jpg to C:\Users\Asus\Desktop\Pre\test\column\416.jpg
# Processed and saved: 417.jpg to C:\Users\Asus\Desktop\Pre\test\column\417.jpg
# Processed and saved: 418.jpg to C:\Users\Asus\Desktop\Pre\test\column\418.jpg
# Processed and saved: 419.jpg to C:\Users\Asus\Desktop\Pre\test\column\419.jpg
# Processed and saved: 420.jpg to C:\Users\Asus\Desktop\Pre\test\column\420.jpg
# Processed and saved: 421.jpg to C:\Users\Asus\Desktop\Pre\test\column\421.jpg
# Processed and saved: 422.jpg to C:\Users\Asus\Desktop\Pre\test\column\422.jpg
# Processed and saved: 423.jpg to C:\Users\Asus\Desktop\Pre\test\column\423.jpg
# Processed and saved: 424.jpg to C:\Users\Asus\Desktop\Pre\test\column\424.jpg
# Processed and saved: 425.jpg to C:\Users\Asus\Desktop\Pre\test\column\425.jpg
# Processed and saved: 426.jpg to C:\Users\Asus\Desktop\Pre\test\column\426.jpg
# Processed and saved: 427.jpg to C:\Users\Asus\Desktop\Pre\test\column\427.jpg
# Processed and saved: 428.jpg to C:\Users\Asus\Desktop\Pre\test\column\428.jpg
# Processed and saved: 429.jpg to C:\Users\Asus\Desktop\Pre\test\column\429.jpg
# Processed and saved: 430.jpg to C:\Users\Asus\Desktop\Pre\test\column\430.jpg
# Processed and saved: 431.jpg to C:\Users\Asus\Desktop\Pre\test\column\431.jpg
# Processed and saved: 432.jpg to C:\Users\Asus\Desktop\Pre\test\column\432.jpg
# Processed and saved: 433.jpg to C:\Users\Asus\Desktop\Pre\test\column\433.jpg
# Processed and saved: 434.jpg to C:\Users\Asus\Desktop\Pre\test\column\434.jpg
# Processed and saved: 435.jpg to C:\Users\Asus\Desktop\Pre\test\column\435.jpg
# Processed and saved: 436.jpg to C:\Users\Asus\Desktop\Pre\test\column\436.jpg
# Processed and saved: 437.jpg to C:\Users\Asus\Desktop\Pre\test\column\437.jpg
# Processed and saved: 438.jpg to C:\Users\Asus\Desktop\Pre\test\column\438.jpg
# Processed and saved: 439.jpg to C:\Users\Asus\Desktop\Pre\test\column\439.jpg
# Processed and saved: 440.jpg to C:\Users\Asus\Desktop\Pre\test\column\440.jpg
# Processed and saved: 441.jpg to C:\Users\Asus\Desktop\Pre\test\column\441.jpg
# Processed and saved: 442.jpg to C:\Users\Asus\Desktop\Pre\test\column\442.jpg
# Processed and saved: 443.jpg to C:\Users\Asus\Desktop\Pre\test\column\443.jpg
# Processed and saved: 444.jpg to C:\Users\Asus\Desktop\Pre\test\column\444.jpg
# Processed and saved: 445.jpg to C:\Users\Asus\Desktop\Pre\test\column\445.jpg
# Processed and saved: 446.jpg to C:\Users\Asus\Desktop\Pre\test\column\446.jpg
# Processed and saved: 447.jpg to C:\Users\Asus\Desktop\Pre\test\column\447.jpg
# Processed and saved: 448.jpg to C:\Users\Asus\Desktop\Pre\test\column\448.jpg
# Processed and saved: 449.jpg to C:\Users\Asus\Desktop\Pre\test\column\449.jpg
# Processed and saved: 450.jpg to C:\Users\Asus\Desktop\Pre\test\column\450.jpg
# Processed and saved: 451.jpg to C:\Users\Asus\Desktop\Pre\test\column\451.jpg
# Processed and saved: 452.jpg to C:\Users\Asus\Desktop\Pre\test\column\452.jpg
# Processed and saved: 453.jpg to C:\Users\Asus\Desktop\Pre\test\column\453.jpg
# Processed and saved: 454.jpg to C:\Users\Asus\Desktop\Pre\test\column\454.jpg
# Processed and saved: 455.jpg to C:\Users\Asus\Desktop\Pre\test\column\455.jpg
# Processed and saved: 456.jpg to C:\Users\Asus\Desktop\Pre\test\column\456.jpg
# Processed and saved: 457.jpg to C:\Users\Asus\Desktop\Pre\test\column\457.jpg
# Processed and saved: 458.jpg to C:\Users\Asus\Desktop\Pre\test\column\458.jpg
# Processed and saved: 459.jpg to C:\Users\Asus\Desktop\Pre\test\column\459.jpg
# Processed and saved: 460.jpg to C:\Users\Asus\Desktop\Pre\test\column\460.jpg
# Processed and saved: 461.jpg to C:\Users\Asus\Desktop\Pre\test\column\461.jpg
# Processed and saved: 462.jpg to C:\Users\Asus\Desktop\Pre\test\column\462.jpg
# Processed and saved: 463.jpg to C:\Users\Asus\Desktop\Pre\test\column\463.jpg
# Processed and saved: 464.jpg to C:\Users\Asus\Desktop\Pre\test\column\464.jpg
# Processed and saved: 465.jpg to C:\Users\Asus\Desktop\Pre\test\column\465.jpg
# Processed and saved: 466.jpg to C:\Users\Asus\Desktop\Pre\test\column\466.jpg
# Processed and saved: 467.jpg to C:\Users\Asus\Desktop\Pre\test\column\467.jpg
# Processed and saved: 468.jpg to C:\Users\Asus\Desktop\Pre\test\column\468.jpg
# Processed and saved: 469.jpg to C:\Users\Asus\Desktop\Pre\test\column\469.jpg
# Processed and saved: 470.jpg to C:\Users\Asus\Desktop\Pre\test\column\470.jpg
# Processed and saved: 471.jpg to C:\Users\Asus\Desktop\Pre\test\column\471.jpg
# Processed and saved: 472.jpg to C:\Users\Asus\Desktop\Pre\test\column\472.jpg
# Processed and saved: 473.jpg to C:\Users\Asus\Desktop\Pre\test\column\473.jpg
# Processed and saved: 474.jpg to C:\Users\Asus\Desktop\Pre\test\column\474.jpg
# Processed and saved: 475.jpg to C:\Users\Asus\Desktop\Pre\test\column\475.jpg
# Processed and saved: 476.jpg to C:\Users\Asus\Desktop\Pre\test\column\476.jpg
# Processed and saved: 477.jpg to C:\Users\Asus\Desktop\Pre\test\column\477.jpg
# Processed and saved: 478.jpg to C:\Users\Asus\Desktop\Pre\test\column\478.jpg
# Processed and saved: 479.jpg to C:\Users\Asus\Desktop\Pre\test\column\479.jpg
# Processed and saved: 480.jpg to C:\Users\Asus\Desktop\Pre\test\column\480.jpg
# Processed and saved: 481.jpg to C:\Users\Asus\Desktop\Pre\test\column\481.jpg
# Processed and saved: 482.jpg to C:\Users\Asus\Desktop\Pre\test\column\482.jpg
# Processed and saved: 483.jpg to C:\Users\Asus\Desktop\Pre\test\column\483.jpg
# Processed and saved: 484.jpg to C:\Users\Asus\Desktop\Pre\test\column\484.jpg
# Processed and saved: 485.jpg to C:\Users\Asus\Desktop\Pre\test\column\485.jpg
# Processed and saved: 486.jpg to C:\Users\Asus\Desktop\Pre\test\column\486.jpg
# Processed and saved: 487.jpg to C:\Users\Asus\Desktop\Pre\test\column\487.jpg
# Processed and saved: 488.jpg to C:\Users\Asus\Desktop\Pre\test\column\488.jpg
# Processed and saved: 489.jpg to C:\Users\Asus\Desktop\Pre\test\column\489.jpg
# Processed and saved: 490.jpg to C:\Users\Asus\Desktop\Pre\test\column\490.jpg
# Processed and saved: 491.jpg to C:\Users\Asus\Desktop\Pre\test\column\491.jpg
# Processed and saved: 492.jpg to C:\Users\Asus\Desktop\Pre\test\column\492.jpg
# Processed and saved: 493.jpg to C:\Users\Asus\Desktop\Pre\test\column\493.jpg
# Processed and saved: 494.jpg to C:\Users\Asus\Desktop\Pre\test\column\494.jpg
# Processed and saved: 495.jpg to C:\Users\Asus\Desktop\Pre\test\column\495.jpg
# Processed and saved: 496.jpg to C:\Users\Asus\Desktop\Pre\test\column\496.jpg
# Processed and saved: 497.jpg to C:\Users\Asus\Desktop\Pre\test\column\497.jpg
# Processed and saved: 498.jpg to C:\Users\Asus\Desktop\Pre\test\column\498.jpg
# Processed and saved: 499.jpg to C:\Users\Asus\Desktop\Pre\test\column\499.jpg
# Processed and saved: 500.jpg to C:\Users\Asus\Desktop\Pre\test\column\500.jpg
# Processed and saved: 501.jpg to C:\Users\Asus\Desktop\Pre\test\column\501.jpg
# Processed and saved: 502.jpg to C:\Users\Asus\Desktop\Pre\test\column\502.jpg
# Processed and saved: 503.jpg to C:\Users\Asus\Desktop\Pre\test\column\503.jpg
# Processed and saved: 504.jpg to C:\Users\Asus\Desktop\Pre\test\column\504.jpg
# Processed and saved: 505.jpg to C:\Users\Asus\Desktop\Pre\test\column\505.jpg
# Processed and saved: 506.jpg to C:\Users\Asus\Desktop\Pre\test\column\506.jpg
# Processed and saved: 507.jpg to C:\Users\Asus\Desktop\Pre\test\column\507.jpg
# Processed and saved: 508.jpg to C:\Users\Asus\Desktop\Pre\test\column\508.jpg
# Processed and saved: 509.jpg to C:\Users\Asus\Desktop\Pre\test\column\509.jpg
# Processed and saved: 510.jpg to C:\Users\Asus\Desktop\Pre\test\column\510.jpg
# Processed and saved: 511.jpg to C:\Users\Asus\Desktop\Pre\test\column\511.jpg
# Processed and saved: 512.jpg to C:\Users\Asus\Desktop\Pre\test\column\512.jpg
# Processed and saved: 513.jpg to C:\Users\Asus\Desktop\Pre\test\column\513.jpg
# Processed and saved: 514.jpg to C:\Users\Asus\Desktop\Pre\test\column\514.jpg
# Processed and saved: 515.jpg to C:\Users\Asus\Desktop\Pre\test\column\515.jpg
# Processed and saved: 516.jpg to C:\Users\Asus\Desktop\Pre\test\column\516.jpg
# Processed and saved: 517.jpg to C:\Users\Asus\Desktop\Pre\test\column\517.jpg
# Processed and saved: 518.jpg to C:\Users\Asus\Desktop\Pre\test\column\518.jpg
# Processed and saved: 519.jpg to C:\Users\Asus\Desktop\Pre\test\column\519.jpg
# Processed and saved: 520.jpg to C:\Users\Asus\Desktop\Pre\test\column\520.jpg
# Processed and saved: 521.jpg to C:\Users\Asus\Desktop\Pre\test\column\521.jpg
# Processed and saved: 522.jpg to C:\Users\Asus\Desktop\Pre\test\column\522.jpg
# Processed and saved: 523.jpg to C:\Users\Asus\Desktop\Pre\test\column\523.jpg
# Processed and saved: 524.jpg to C:\Users\Asus\Desktop\Pre\test\column\524.jpg
# Processed and saved: 525.jpg to C:\Users\Asus\Desktop\Pre\test\column\525.jpg
# Processed and saved: 526.jpg to C:\Users\Asus\Desktop\Pre\test\column\526.jpg
# Processed and saved: 527.jpg to C:\Users\Asus\Desktop\Pre\test\column\527.jpg
# Processed and saved: 528.jpg to C:\Users\Asus\Desktop\Pre\test\column\528.jpg
# Processed and saved: 529.jpg to C:\Users\Asus\Desktop\Pre\test\column\529.jpg
# Processed and saved: 530.jpg to C:\Users\Asus\Desktop\Pre\test\column\530.jpg
# Processed and saved: 531.jpg to C:\Users\Asus\Desktop\Pre\test\column\531.jpg
# Processed and saved: 532.jpg to C:\Users\Asus\Desktop\Pre\test\column\532.jpg
# Processed and saved: 533.jpg to C:\Users\Asus\Desktop\Pre\test\column\533.jpg
# Processed and saved: 534.jpg to C:\Users\Asus\Desktop\Pre\test\column\534.jpg
# Processed and saved: 535.jpg to C:\Users\Asus\Desktop\Pre\test\column\535.jpg
# Processed and saved: 536.jpg to C:\Users\Asus\Desktop\Pre\test\column\536.jpg
# Processed and saved: 537.jpg to C:\Users\Asus\Desktop\Pre\test\column\537.jpg
# Processed and saved: 538.jpg to C:\Users\Asus\Desktop\Pre\test\column\538.jpg
# Processed and saved: 539.jpg to C:\Users\Asus\Desktop\Pre\test\column\539.jpg
# Processed and saved: 540.jpg to C:\Users\Asus\Desktop\Pre\test\column\540.jpg
# Processed and saved: 541.jpg to C:\Users\Asus\Desktop\Pre\test\column\541.jpg
# Processed and saved: 542.jpg to C:\Users\Asus\Desktop\Pre\test\column\542.jpg
# Processed and saved: 543.jpg to C:\Users\Asus\Desktop\Pre\test\column\543.jpg
# Processed and saved: 544.jpg to C:\Users\Asus\Desktop\Pre\test\column\544.jpg
# Processed and saved: 545.jpg to C:\Users\Asus\Desktop\Pre\test\column\545.jpg
# Processed and saved: 546.jpg to C:\Users\Asus\Desktop\Pre\test\column\546.jpg
# Processed and saved: 547.jpg to C:\Users\Asus\Desktop\Pre\test\column\547.jpg
# Processed and saved: 548.jpg to C:\Users\Asus\Desktop\Pre\test\column\548.jpg
# Processed and saved: 549.jpg to C:\Users\Asus\Desktop\Pre\test\column\549.jpg
# Processed and saved: 550.jpg to C:\Users\Asus\Desktop\Pre\test\column\550.jpg
# Processed and saved: 551.jpg to C:\Users\Asus\Desktop\Pre\test\column\551.jpg
# Processed and saved: 552.jpg to C:\Users\Asus\Desktop\Pre\test\column\552.jpg
# Processed and saved: 553.jpg to C:\Users\Asus\Desktop\Pre\test\column\553.jpg
# Processed and saved: 554.jpg to C:\Users\Asus\Desktop\Pre\test\column\554.jpg
# Processed and saved: 555.jpg to C:\Users\Asus\Desktop\Pre\test\column\555.jpg
# Processed and saved: 556.jpg to C:\Users\Asus\Desktop\Pre\test\column\556.jpg
# Processed and saved: 557.jpg to C:\Users\Asus\Desktop\Pre\test\column\557.jpg
# Processed and saved: 558.jpg to C:\Users\Asus\Desktop\Pre\test\column\558.jpg
# Processed and saved: 559.jpg to C:\Users\Asus\Desktop\Pre\test\column\559.jpg
# Processed and saved: 560.jpg to C:\Users\Asus\Desktop\Pre\test\column\560.jpg
# Processed and saved: 561.jpg to C:\Users\Asus\Desktop\Pre\test\column\561.jpg
# Processed and saved: 562.jpg to C:\Users\Asus\Desktop\Pre\test\column\562.jpg
# Processed and saved: 563.jpg to C:\Users\Asus\Desktop\Pre\test\column\563.jpg
# Processed and saved: 564.jpg to C:\Users\Asus\Desktop\Pre\test\column\564.jpg
# Processed and saved: 565.jpg to C:\Users\Asus\Desktop\Pre\test\column\565.jpg
# Processed and saved: 566.jpg to C:\Users\Asus\Desktop\Pre\test\column\566.jpg
# Processed and saved: 567.jpg to C:\Users\Asus\Desktop\Pre\test\column\567.jpg
# Processed and saved: 568.jpg to C:\Users\Asus\Desktop\Pre\test\column\568.jpg
# Processed and saved: 569.jpg to C:\Users\Asus\Desktop\Pre\test\column\569.jpg
# Processed and saved: 875.jpg to C:\Users\Asus\Desktop\Pre\test\dome(inner)\875.jpg
# Processed and saved: 876.jpg to C:\Users\Asus\Desktop\Pre\test\dome(inner)\876.jpg
# Processed and saved: 877.jpg to C:\Users\Asus\Desktop\Pre\test\dome(inner)\877.jpg
# Processed and saved: 878.jpg to C:\Users\Asus\Desktop\Pre\test\dome(inner)\878.jpg
# Processed and saved: 879.jpg to C:\Users\Asus\Desktop\Pre\test\dome(inner)\879.jpg
# Processed and saved: 880.jpg to C:\Users\Asus\Desktop\Pre\test\dome(inner)\880.jpg
# Processed and saved: 881.jpg to C:\Users\Asus\Desktop\Pre\test\dome(inner)\881.jpg
# Processed and saved: 882.jpg to C:\Users\Asus\Desktop\Pre\test\dome(inner)\882.jpg
# Processed and saved: 883.jpg to C:\Users\Asus\Desktop\Pre\test\dome(inner)\883.jpg
# Processed and saved: 884.jpg to C:\Users\Asus\Desktop\Pre\test\dome(inner)\884.jpg
# Processed and saved: 885.jpg to C:\Users\Asus\Desktop\Pre\test\dome(inner)\885.jpg
# Processed and saved: 886.jpg to C:\Users\Asus\Desktop\Pre\test\dome(inner)\886.jpg
# Processed and saved: 887.jpg to C:\Users\Asus\Desktop\Pre\test\dome(inner)\887.jpg
# Processed and saved: 888.jpg to C:\Users\Asus\Desktop\Pre\test\dome(inner)\888.jpg
# Processed and saved: 889.jpg to C:\Users\Asus\Desktop\Pre\test\dome(inner)\889.jpg
# Processed and saved: 890.jpg to C:\Users\Asus\Desktop\Pre\test\dome(inner)\890.jpg
# Processed and saved: 891.jpg to C:\Users\Asus\Desktop\Pre\test\dome(inner)\891.jpg
# Processed and saved: 892.jpg to C:\Users\Asus\Desktop\Pre\test\dome(inner)\892.jpg
# Processed and saved: 893.jpg to C:\Users\Asus\Desktop\Pre\test\dome(inner)\893.jpg
# Processed and saved: 894.jpg to C:\Users\Asus\Desktop\Pre\test\dome(inner)\894.jpg
# Processed and saved: 895.jpg to C:\Users\Asus\Desktop\Pre\test\dome(inner)\895.jpg
# Processed and saved: 896.jpg to C:\Users\Asus\Desktop\Pre\test\dome(inner)\896.jpg
# Processed and saved: 897.jpg to C:\Users\Asus\Desktop\Pre\test\dome(inner)\897.jpg
# Processed and saved: 898.jpg to C:\Users\Asus\Desktop\Pre\test\dome(inner)\898.jpg
# Processed and saved: 899.jpg to C:\Users\Asus\Desktop\Pre\test\dome(inner)\899.jpg
# Processed and saved: 900.jpg to C:\Users\Asus\Desktop\Pre\test\dome(inner)\900.jpg
# Processed and saved: 901.jpg to C:\Users\Asus\Desktop\Pre\test\dome(inner)\901.jpg
# Processed and saved: 902.jpg to C:\Users\Asus\Desktop\Pre\test\dome(inner)\902.jpg
# Processed and saved: 903.jpg to C:\Users\Asus\Desktop\Pre\test\dome(inner)\903.jpg
# Processed and saved: 904.jpg to C:\Users\Asus\Desktop\Pre\test\dome(inner)\904.jpg
# Processed and saved: 905.jpg to C:\Users\Asus\Desktop\Pre\test\dome(inner)\905.jpg
# Processed and saved: 906.jpg to C:\Users\Asus\Desktop\Pre\test\dome(inner)\906.jpg
# Processed and saved: 907.jpg to C:\Users\Asus\Desktop\Pre\test\dome(inner)\907.jpg
# ...
# Processed and saved: 9410.jpg to C:\Users\Asus\Desktop\Pre\train\vault\9410.jpg
# Processed and saved: 9411.jpg to C:\Users\Asus\Desktop\Pre\train\vault\9411.jpg
# Processed and saved: 9412.jpg to C:\Users\Asus\Desktop\Pre\train\vault\9412.jpg
# Processed and saved: 9413.jpg to C:\Users\Asus\Desktop\Pre\train\vault\9413.jpg
# Processed and saved: 9414.jpg to C:\Users\Asus\Desktop\Pre\train\vault\9414.jpg
# Processed and saved: 9415.jpg to C:\Users\Asus\Desktop\Pre\train\vault\9415.jpg
# Processed and saved: 9416.jpg to C:\Users\Asus\Desktop\Pre\train\vault\9416.jpg
# Processed and saved: 9417.jpg to C:\Users\Asus\Desktop\Pre\train\vault\9417.jpg
# Processed and saved: 9418.jpg to C:\Users\Asus\Desktop\Pre\train\vault\9418.jpg
# Processed and saved: 9419.jpg to C:\Users\Asus\Desktop\Pre\train\vault\9419.jpg
# Processed and saved: 9420.jpg to C:\Users\Asus\Desktop\Pre\train\vault\9420.jpg
# Processed and saved: 9421.jpg to C:\Users\Asus\Desktop\Pre\train\vault\9421.jpg
# Processed and saved: 9422.jpg to C:\Users\Asus\Desktop\Pre\train\vault\9422.jpg
# Processed and saved: 9423.jpg to C:\Users\Asus\Desktop\Pre\train\vault\9423.jpg
# Processed and saved: 9424.jpg to C:\Users\Asus\Desktop\Pre\train\vault\9424.jpg
# Processed and saved: 9425.jpg to C:\Users\Asus\Desktop\Pre\train\vault\9425.jpg
# Processed and saved: 9426.jpg to C:\Users\Asus\Desktop\Pre\train\vault\9426.jpg
# Processed and saved: 9427.jpg to C:\Users\Asus\Desktop\Pre\train\vault\9427.jpg
# Processed and saved: 9428.jpg to C:\Users\Asus\Desktop\Pre\train\vault\9428.jpg
# Processed and saved: 9429.jpg to C:\Users\Asus\Desktop\Pre\train\vault\9429.jpg
# Processed and saved: 9430.jpg to C:\Users\Asus\Desktop\Pre\train\vault\9430.jpg
# Processed and saved: 9431.jpg to C:\Users\Asus\Desktop\Pre\train\vault\9431.jpg
# Processed and saved: 9432.jpg to C:\Users\Asus\Desktop\Pre\train\vault\9432.jpg
# Processed and saved: 9433.jpg to C:\Users\Asus\Desktop\Pre\train\vault\9433.jpg
# Processed and saved: 9434.jpg to C:\Users\Asus\Desktop\Pre\train\vault\9434.jpg
# Processed and saved: 9435.jpg to C:\Users\Asus\Desktop\Pre\train\vault\9435.jpg
# Processed and saved: 9436.jpg to C:\Users\Asus\Desktop\Pre\train\vault\9436.jpg
# Processed and saved: 9437.jpg to C:\Users\Asus\Desktop\Pre\train\vault\9437.jpg
# Processed and saved: 9438.jpg to C:\Users\Asus\Desktop\Pre\train\vault\9438.jpg
# Processed and saved: 9439.jpg to C:\Users\Asus\Desktop\Pre\train\vault\9439.jpg
# Processed and saved: 9440.jpg to C:\Users\Asus\Desktop\Pre\train\vault\9440.jpg
# Processed and saved: 9441.jpg to C:\Users\Asus\Desktop\Pre\train\vault\9441.jpg
# Processed and saved: 9442.jpg to C:\Users\Asus\Desktop\Pre\train\vault\9442.jpg
# Processed and saved: 9443.jpg to C:\Users\Asus\Desktop\Pre\train\vault\9443.jpg
# Processed and saved: 9444.jpg to C:\Users\Asus\Desktop\Pre\train\vault\9444.jpg
# Processed and saved: 9445.jpg to C:\Users\Asus\Desktop\Pre\train\vault\9445.jpg
# Processed and saved: 9446.jpg to C:\Users\Asus\Desktop\Pre\train\vault\9446.jpg
# Processed and saved: 9447.jpg to C:\Users\Asus\Desktop\Pre\train\vault\9447.jpg
# Processed and saved: 9448.jpg to C:\Users\Asus\Desktop\Pre\train\vault\9448.jpg
# Processed and saved: 9449.jpg to C:\Users\Asus\Desktop\Pre\train\vault\9449.jpg
# Processed and saved: 9450.jpg to C:\Users\Asus\Desktop\Pre\train\vault\9450.jpg
# Processed and saved: 9451.jpg to C:\Users\Asus\Desktop\Pre\train\vault\9451.jpg
# Processed and saved: 9452.jpg to C:\Users\Asus\Desktop\Pre\train\vault\9452.jpg
# Processed and saved: 9453.jpg to C:\Users\Asus\Desktop\Pre\train\vault\9453.jpg
# Processed and saved: 9454.jpg to C:\Users\Asus\Desktop\Pre\train\vault\9454.jpg
# Processed and saved: 9455.jpg to C:\Users\Asus\Desktop\Pre\train\vault\9455.jpg
# Processed and saved: 9456.jpg to C:\Users\Asus\Desktop\Pre\train\vault\9456.jpg
# Processed and saved: 9457.jpg to C:\Users\Asus\Desktop\Pre\train\vault\9457.jpg
# Processed and saved: 9458.jpg to C:\Users\Asus\Desktop\Pre\train\vault\9458.jpg
# Processed and saved: 9459.jpg to C:\Users\Asus\Desktop\Pre\train\vault\9459.jpg
# Processed and saved: 9460.jpg to C:\Users\Asus\Desktop\Pre\train\vault\9460.jpg
# Processed and saved: 9461.jpg to C:\Users\Asus\Desktop\Pre\train\vault\9461.jpg
# Processed and saved: 9462.jpg to C:\Users\Asus\Desktop\Pre\train\vault\9462.jpg
# Processed and saved: 9463.jpg to C:\Users\Asus\Desktop\Pre\train\vault\9463.jpg
# Processed and saved: 9464.jpg to C:\Users\Asus\Desktop\Pre\train\vault\9464.jpg
# Processed and saved: 9465.jpg to C:\Users\Asus\Desktop\Pre\train\vault\9465.jpg
# Processed and saved: 9466.jpg to C:\Users\Asus\Desktop\Pre\train\vault\9466.jpg
# Processed and saved: 9467.jpg to C:\Users\Asus\Desktop\Pre\train\vault\9467.jpg
# Processed and saved: 9468.jpg to C:\Users\Asus\Desktop\Pre\train\vault\9468.jpg
# Processed and saved: 9469.jpg to C:\Users\Asus\Desktop\Pre\train\vault\9469.jpg
# Processed and saved: 9470.jpg to C:\Users\Asus\Desktop\Pre\train\vault\9470.jpg
# Processed and saved: 9471.jpg to C:\Users\Asus\Desktop\Pre\train\vault\9471.jpg
# Processed and saved: 9472.jpg to C:\Users\Asus\Desktop\Pre\train\vault\9472.jpg
# Processed and saved: 9473.jpg to C:\Users\Asus\Desktop\Pre\train\vault\9473.jpg
# Processed and saved: 9474.jpg to C:\Users\Asus\Desktop\Pre\train\vault\9474.jpg
# Processed and saved: 9475.jpg to C:\Users\Asus\Desktop\Pre\train\vault\9475.jpg
# Processed and saved: 9476.jpg to C:\Users\Asus\Desktop\Pre\train\vault\9476.jpg
# Processed and saved: 9477.jpg to C:\Users\Asus\Desktop\Pre\train\vault\9477.jpg
# Processed and saved: 9478.jpg to C:\Users\Asus\Desktop\Pre\train\vault\9478.jpg
# Processed and saved: 9479.jpg to C:\Users\Asus\Desktop\Pre\train\vault\9479.jpg
# Processed and saved: 9480.jpg to C:\Users\Asus\Desktop\Pre\train\vault\9480.jpg
# Processed and saved: 9481.jpg to C:\Users\Asus\Desktop\Pre\train\vault\9481.jpg
# Processed and saved: 9482.jpg to C:\Users\Asus\Desktop\Pre\train\vault\9482.jpg
# Processed and saved: 9483.jpg to C:\Users\Asus\Desktop\Pre\train\vault\9483.jpg
# Processed and saved: 9484.jpg to C:\Users\Asus\Desktop\Pre\train\vault\9484.jpg
# Processed and saved: 9485.jpg to C:\Users\Asus\Desktop\Pre\train\vault\9485.jpg
# Processed and saved: 9486.jpg to C:\Users\Asus\Desktop\Pre\train\vault\9486.jpg
# Processed and saved: 9487.jpg to C:\Users\Asus\Desktop\Pre\train\vault\9487.jpg
# Processed and saved: 9488.jpg to C:\Users\Asus\Desktop\Pre\train\vault\9488.jpg
# Processed and saved: 9489.jpg to C:\Users\Asus\Desktop\Pre\train\vault\9489.jpg
# Processed and saved: 9490.jpg to C:\Users\Asus\Desktop\Pre\train\vault\9490.jpg
# Processed and saved: 9491.jpg to C:\Users\Asus\Desktop\Pre\train\vault\9491.jpg
# Processed and saved: 9492.jpg to C:\Users\Asus\Desktop\Pre\train\vault\9492.jpg
# Processed and saved: 9493.jpg to C:\Users\Asus\Desktop\Pre\train\vault\9493.jpg
# Processed and saved: 9494.jpg to C:\Users\Asus\Desktop\Pre\train\vault\9494.jpg
# Processed and saved: 9495.jpg to C:\Users\Asus\Desktop\Pre\train\vault\9495.jpg
# Processed and saved: 9496.jpg to C:\Users\Asus\Desktop\Pre\train\vault\9496.jpg
# Processed and saved: 9497.jpg to C:\Users\Asus\Desktop\Pre\train\vault\9497.jpg
# Processed and saved: 9498.jpg to C:\Users\Asus\Desktop\Pre\train\vault\9498.jpg
# Processed and saved: 9499.jpg to C:\Users\Asus\Desktop\Pre\train\vault\9499.jpg
# Processed and saved: 9500.jpg to C:\Users\Asus\Desktop\Pre\train\vault\9500.jpg
# Processed and saved: 9501.jpg to C:\Users\Asus\Desktop\Pre\train\vault\9501.jpg
# Processed and saved: 9502.jpg to C:\Users\Asus\Desktop\Pre\train\vault\9502.jpg
# Processed and saved: 9503.jpg to C:\Users\Asus\Desktop\Pre\train\vault\9503.jpg
# Processed and saved: 9504.jpg to C:\Users\Asus\Desktop\Pre\train\vault\9504.jpg
# Processed and saved: 9505.jpg to C:\Users\Asus\Desktop\Pre\train\vault\9505.jpg
# Processed and saved: 9506.jpg to C:\Users\Asus\Desktop\Pre\train\vault\9506.jpg
# Processed and saved: 9507.jpg to C:\Users\Asus\Desktop\Pre\train\vault\9507.jpg
# Processed and saved: 9508.jpg to C:\Users\Asus\Desktop\Pre\train\vault\9508.jpg
# Processed and saved: 9509.jpg to C:\Users\Asus\Desktop\Pre\train\vault\9509.jpg
# Processed and saved: 9510.jpg to C:\Users\Asus\Desktop\Pre\train\vault\9510.jpg
# Processed and saved: 9511.jpg to C:\Users\Asus\Desktop\Pre\train\vault\9511.jpg
# Processed and saved: 9512.jpg to C:\Users\Asus\Desktop\Pre\train\vault\9512.jpg
# Processed and saved: 9513.jpg to C:\Users\Asus\Desktop\Pre\train\vault\9513.jpg
# Processed and saved: 9514.jpg to C:\Users\Asus\Desktop\Pre\train\vault\9514.jpg
# Processed and saved: 9515.jpg to C:\Users\Asus\Desktop\Pre\train\vault\9515.jpg
# Processed and saved: 9516.jpg to C:\Users\Asus\Desktop\Pre\train\vault\9516.jpg
# Processed and saved: 9517.jpg to C:\Users\Asus\Desktop\Pre\train\vault\9517.jpg
# Processed and saved: 9518.jpg to C:\Users\Asus\Desktop\Pre\train\vault\9518.jpg
# Processed and saved: 9519.jpg to C:\Users\Asus\Desktop\Pre\train\vault\9519.jpg
# Processed and saved: 9520.jpg to C:\Users\Asus\Desktop\Pre\train\vault\9520.jpg
# Processed and saved: 9521.jpg to C:\Users\Asus\Desktop\Pre\train\vault\9521.jpg
# Processed and saved: 9522.jpg to C:\Users\Asus\Desktop\Pre\train\vault\9522.jpg
# Processed and saved: 9523.jpg to C:\Users\Asus\Desktop\Pre\train\vault\9523.jpg
# Processed and saved: 9524.jpg to C:\Users\Asus\Desktop\Pre\train\vault\9524.jpg
# Processed and saved: 9525.jpg to C:\Users\Asus\Desktop\Pre\train\vault\9525.jpg
# Processed and saved: 9526.jpg to C:\Users\Asus\Desktop\Pre\train\vault\9526.jpg
# Processed and saved: 9527.jpg to C:\Users\Asus\Desktop\Pre\train\vault\9527.jpg
# Processed and saved: 9528.jpg to C:\Users\Asus\Desktop\Pre\train\vault\9528.jpg
# Processed and saved: 9529.jpg to C:\Users\Asus\Desktop\Pre\train\vault\9529.jpg
# Processed and saved: 9530.jpg to C:\Users\Asus\Desktop\Pre\train\vault\9530.jpg
# Processed and saved: 9531.jpg to C:\Users\Asus\Desktop\Pre\train\vault\9531.jpg
# Processed and saved: 9532.jpg to C:\Users\Asus\Desktop\Pre\train\vault\9532.jpg
# Processed and saved: 9533.jpg to C:\Users\Asus\Desktop\Pre\train\vault\9533.jpg
# Processed and saved: 9534.jpg to C:\Users\Asus\Desktop\Pre\train\vault\9534.jpg
# Processed and saved: 9535.jpg to C:\Users\Asus\Desktop\Pre\train\vault\9535.jpg
# Processed and saved: 9536.jpg to C:\Users\Asus\Desktop\Pre\train\vault\9536.jpg
# Processed and saved: 9537.jpg to C:\Users\Asus\Desktop\Pre\train\vault\9537.jpg
# Processed and saved: 9538.jpg to C:\Users\Asus\Desktop\Pre\train\vault\9538.jpg
# Processed and saved: 9539.jpg to C:\Users\Asus\Desktop\Pre\train\vault\9539.jpg
# Processed and saved: 9540.jpg to C:\Users\Asus\Desktop\Pre\train\vault\9540.jpg
# Processed and saved: 9541.jpg to C:\Users\Asus\Desktop\Pre\train\vault\9541.jpg
# Processed and saved: 9542.jpg to C:\Users\Asus\Desktop\Pre\train\vault\9542.jpg
# Processed and saved: 9543.jpg to C:\Users\Asus\Desktop\Pre\train\vault\9543.jpg
# Processed and saved: 9544.jpg to C:\Users\Asus\Desktop\Pre\train\vault\9544.jpg
# Processed and saved: 9545.jpg to C:\Users\Asus\Desktop\Pre\train\vault\9545.jpg
# Processed and saved: 9546.jpg to C:\Users\Asus\Desktop\Pre\train\vault\9546.jpg
# Processed and saved: 9547.jpg to C:\Users\Asus\Desktop\Pre\train\vault\9547.jpg
# Processed and saved: 9548.jpg to C:\Users\Asus\Desktop\Pre\train\vault\9548.jpg
# Processed and saved: 9549.jpg to C:\Users\Asus\Desktop\Pre\train\vault\9549.jpg
# Processed and saved: 9550.jpg to C:\Users\Asus\Desktop\Pre\train\vault\9550.jpg
# Processed and saved: 9551.jpg to C:\Users\Asus\Desktop\Pre\train\vault\9551.jpg
# Processed and saved: 9552.jpg to C:\Users\Asus\Desktop\Pre\train\vault\9552.jpg
# Processed and saved: 9553.jpg to C:\Users\Asus\Desktop\Pre\train\vault\9553.jpg
# Processed and saved: 9554.jpg to C:\Users\Asus\Desktop\Pre\train\vault\9554.jpg
# Processed and saved: 9555.jpg to C:\Users\Asus\Desktop\Pre\train\vault\9555.jpg
# Processed and saved: 9556.jpg to C:\Users\Asus\Desktop\Pre\train\vault\9556.jpg
# Processed and saved: 9557.jpg to C:\Users\Asus\Desktop\Pre\train\vault\9557.jpg
# Processed and saved: 9558.jpg to C:\Users\Asus\Desktop\Pre\train\vault\9558.jpg
# Processed and saved: 9559.jpg to C:\Users\Asus\Desktop\Pre\train\vault\9559.jpg
# Processed and saved: 9560.jpg to C:\Users\Asus\Desktop\Pre\train\vault\9560.jpg
# Processed and saved: 9561.jpg to C:\Users\Asus\Desktop\Pre\train\vault\9561.jpg
# Processed and saved: 9562.jpg to C:\Users\Asus\Desktop\Pre\train\vault\9562.jpg
# Processed and saved: 9563.jpg to C:\Users\Asus\Desktop\Pre\train\vault\9563.jpg
# Processed and saved: 9564.jpg to C:\Users\Asus\Desktop\Pre\train\vault\9564.jpg
# Processed and saved: 9565.jpg to C:\Users\Asus\Desktop\Pre\train\vault\9565.jpg
# Processed and saved: 9566.jpg to C:\Users\Asus\Desktop\Pre\train\vault\9566.jpg
# Processed and saved: 9567.jpg to C:\Users\Asus\Desktop\Pre\train\vault\9567.jpg
# Processed and saved: 9568.jpg to C:\Users\Asus\Desktop\Pre\train\vault\9568.jpg
# Processed and saved: 9569.jpg to C:\Users\Asus\Desktop\Pre\train\vault\9569.jpg
# Processed and saved: 9570.jpg to C:\Users\Asus\Desktop\Pre\train\vault\9570.jpg
# Processed and saved: 9571.jpg to C:\Users\Asus\Desktop\Pre\train\vault\9571.jpg
# Processed and saved: 9572.jpg to C:\Users\Asus\Desktop\Pre\train\vault\9572.jpg
# Processed and saved: 9573.jpg to C:\Users\Asus\Desktop\Pre\train\vault\9573.jpg
# Processed and saved: 9574.jpg to C:\Users\Asus\Desktop\Pre\train\vault\9574.jpg
# Processed and saved: 9575.jpg to C:\Users\Asus\Desktop\Pre\train\vault\9575.jpg
# Processed and saved: 9576.jpg to C:\Users\Asus\Desktop\Pre\train\vault\9576.jpg
# Processed and saved: 9577.jpg to C:\Users\Asus\Desktop\Pre\train\vault\9577.jpg
# Processed and saved: 9578.jpg to C:\Users\Asus\Desktop\Pre\train\vault\9578.jpg
# Processed and saved: 9579.jpg to C:\Users\Asus\Desktop\Pre\train\vault\9579.jpg
# Processed and saved: 9580.jpg to C:\Users\Asus\Desktop\Pre\train\vault\9580.jpg
# Processed and saved: 9581.jpg to C:\Users\Asus\Desktop\Pre\train\vault\9581.jpg
# Processed and saved: 9582.jpg to C:\Users\Asus\Desktop\Pre\train\vault\9582.jpg
# Processed and saved: 9583.jpg to C:\Users\Asus\Desktop\Pre\train\vault\9583.jpg
# Processed and saved: 9584.jpg to C:\Users\Asus\Desktop\Pre\train\vault\9584.jpg
# Processed and saved: 9585.jpg to C:\Users\Asus\Desktop\Pre\train\vault\9585.jpg
# Processed and saved: 9586.jpg to C:\Users\Asus\Desktop\Pre\train\vault\9586.jpg
# Processed and saved: 9587.jpg to C:\Users\Asus\Desktop\Pre\train\vault\9587.jpg
# Processed and saved: 9588.jpg to C:\Users\Asus\Desktop\Pre\train\vault\9588.jpg
# Processed and saved: 9589.jpg to C:\Users\Asus\Desktop\Pre\train\vault\9589.jpg
# Processed and saved: 9590.jpg to C:\Users\Asus\Desktop\Pre\train\vault\9590.jpg
# Processed and saved: 9591.jpg to C:\Users\Asus\Desktop\Pre\train\vault\9591.jpg
# Processed and saved: 9592.jpg to C:\Users\Asus\Desktop\Pre\train\vault\9592.jpg
# Processed and saved: 9593.jpg to C:\Users\Asus\Desktop\Pre\train\vault\9593.jpg
# Processed and saved: 9594.jpg to C:\Users\Asus\Desktop\Pre\train\vault\9594.jpg
# Processed and saved: 9595.jpg to C:\Users\Asus\Desktop\Pre\train\vault\9595.jpg
# Processed and saved: 9596.jpg to C:\Users\Asus\Desktop\Pre\train\vault\9596.jpg
# Processed and saved: 9597.jpg to C:\Users\Asus\Desktop\Pre\train\vault\9597.jpg
# Processed and saved: 9598.jpg to C:\Users\Asus\Desktop\Pre\train\vault\9598.jpg
# Processed and saved: 9599.jpg to C:\Users\Asus\Desktop\Pre\train\vault\9599.jpg
# Processed and saved: 9600.jpg to C:\Users\Asus\Desktop\Pre\train\vault\9600.jpg
# Processed and saved: 9601.jpg to C:\Users\Asus\Desktop\Pre\train\vault\9601.jpg
# Processed and saved: 9602.jpg to C:\Users\Asus\Desktop\Pre\train\vault\9602.jpg
# Processed and saved: 9603.jpg to C:\Users\Asus\Desktop\Pre\train\vault\9603.jpg
# Processed and saved: 9604.jpg to C:\Users\Asus\Desktop\Pre\train\vault\9604.jpg
# Processed and saved: 9605.jpg to C:\Users\Asus\Desktop\Pre\train\vault\9605.jpg
# Processed and saved: 9606.jpg to C:\Users\Asus\Desktop\Pre\train\vault\9606.jpg
# Processed and saved: 9607.jpg to C:\Users\Asus\Desktop\Pre\train\vault\9607.jpg
# Processed and saved: 9608.jpg to C:\Users\Asus\Desktop\Pre\train\vault\9608.jpg
# Total number of images processed: 11534

# %%
#BEFORE PRUNING

# %%
import os
import torch
import torchvision.transforms as transforms
from torchvision.datasets import ImageFolder
from torch.utils.data import DataLoader
import torch.nn as nn
import torch.optim as optim
from torchvision.models import mobilenet_v3_small
from torch.utils.tensorboard import SummaryWriter

# Set device
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# Data paths
preprocessed_data_dir = r'C:\Users\Asus\Desktop\Pre-processed'
train_dir = os.path.join(preprocessed_data_dir, 'train')
val_dir = os.path.join(preprocessed_data_dir, 'test')

# Image size and batch size
img_size = (224, 224)
batch_size = 32

# Define transformations
transform = transforms.Compose([
    transforms.Resize(img_size),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])  # Normalization for ImageNet
])

# Load datasets
train_dataset = ImageFolder(train_dir, transform=transform)
val_dataset = ImageFolder(val_dir, transform=transform)

train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)

# Load MobileNetV3
model = mobilenet_v3_small(pretrained=True)

# Replace the classifier layer (no Dropout)
model.classifier[3] = nn.Linear(model.classifier[3].in_features, len(train_dataset.classes))

# Save the pre-pruned model state
torch.save(model.state_dict(), 'mobilenetv3_pre_no_regularization.pth')

# Move model to the device
model.to(device)

# Define loss function and optimizer (no regularization)
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)  # No weight decay

# Train the model
num_epochs = 30
writer = SummaryWriter()

for epoch in range(num_epochs):
    model.train()
    running_loss = 0.0
    correct_train = 0
    total_train = 0

    for images, labels in train_loader:
        images, labels = images.to(device), labels.to(device)
        
        optimizer.zero_grad()
        
        # Forward pass
        outputs = model(images)
        loss = criterion(outputs, labels)
        
        # Backward pass and optimize
        loss.backward()
        optimizer.step()
        
        running_loss += loss.item()

        # Calculate training accuracy
        _, predicted = torch.max(outputs.data, 1)
        total_train += labels.size(0)
        correct_train += (predicted == labels).sum().item()

    avg_loss = running_loss / len(train_loader)
    train_accuracy = 100 * correct_train / total_train
    writer.add_scalar('Loss/train', avg_loss, epoch)
    writer.add_scalar('Accuracy/train', train_accuracy, epoch)

    # Validate the model
    model.eval()
    correct_val = 0
    total_val = 0
    
    with torch.no_grad():
        for images, labels in val_loader:
            images, labels = images.to(device), labels.to(device)
            outputs = model(images)
            _, predicted = torch.max(outputs.data, 1)
            total_val += labels.size(0)
            correct_val += (predicted == labels).sum().item()

    val_accuracy = 100 * correct_val / total_val
    writer.add_scalar('Accuracy/val', val_accuracy, epoch)

    # Print results for the epoch
    print(f'Epoch [{epoch+1}/{num_epochs}], Loss: {avg_loss:.4f}, Train Accuracy: {train_accuracy:.2f}%, Test Accuracy: {val_accuracy:.2f}%')

# Save the trained (final) model
torch.save(model.state_dict(), 'mobilenetv3_final_no_regularization.pth')

writer.close()
# Out:
# Epoch [1/30], Loss: 0.4136, Train Accuracy: 86.70%, Test Accuracy: 82.83%
# Epoch [2/30], Loss: 0.2023, Train Accuracy: 93.45%, Test Accuracy: 87.82%
# Epoch [3/30], Loss: 0.1603, Train Accuracy: 94.84%, Test Accuracy: 88.96%
# Epoch [4/30], Loss: 0.1180, Train Accuracy: 96.16%, Test Accuracy: 79.63%
# Epoch [5/30], Loss: 0.1031, Train Accuracy: 96.54%, Test Accuracy: 89.25%
# Epoch [6/30], Loss: 0.0846, Train Accuracy: 97.15%, Test Accuracy: 89.32%
# Epoch [7/30], Loss: 0.0837, Train Accuracy: 97.41%, Test Accuracy: 88.89%
# Epoch [8/30], Loss: 0.0611, Train Accuracy: 97.99%, Test Accuracy: 89.89%
# Epoch [9/30], Loss: 0.0636, Train Accuracy: 97.96%, Test Accuracy: 90.31%
# Epoch [10/30], Loss: 0.0649, Train Accuracy: 98.09%, Test Accuracy: 87.75%
# Epoch [11/30], Loss: 0.0708, Train Accuracy: 97.86%, Test Accuracy: 90.81%
# Epoch [12/30], Loss: 0.0480, Train Accuracy: 98.54%, Test Accuracy: 88.25%
# Epoch [13/30], Loss: 0.0636, Train Accuracy: 98.02%, Test Accuracy: 90.88%
# Epoch [14/30], Loss: 0.0480, Train Accuracy: 98.30%, Test Accuracy: 90.74%
# Epoch [15/30], Loss: 0.0417, Train Accuracy: 98.63%, Test Accuracy: 90.60%
# Epoch [16/30], Loss: 0.0518, Train Accuracy: 98.38%, Test Accuracy: 87.11%
# Epoch [17/30], Loss: 0.0523, Train Accuracy: 98.59%, Test Accuracy: 89.32%
# Epoch [18/30], Loss: 0.0386, Train Accuracy: 98.69%, Test Accuracy: 88.46%
# Epoch [19/30], Loss: 0.0497, Train Accuracy: 98.43%, Test Accuracy: 88.89%
# Epoch [20/30], Loss: 0.0395, Train Accuracy: 98.77%, Test Accuracy: 86.25%
# Epoch [21/30], Loss: 0.0512, Train Accuracy: 98.50%, Test Accuracy: 87.96%
# Epoch [22/30], Loss: 0.0438, Train Accuracy: 98.73%, Test Accuracy: 89.74%
# Epoch [23/30], Loss: 0.0332, Train Accuracy: 98.90%, Test Accuracy: 90.46%
# Epoch [24/30], Loss: 0.0263, Train Accuracy: 99.22%, Test Accuracy: 90.74%
# Epoch [25/30], Loss: 0.0445, Train Accuracy: 98.67%, Test Accuracy: 79.70%
# Epoch [26/30], Loss: 0.0616, Train Accuracy: 98.07%, Test Accuracy: 87.89%
# Epoch [27/30], Loss: 0.0352, Train Accuracy: 98.92%, Test Accuracy: 88.96%
# Epoch [28/30], Loss: 0.0309, Train Accuracy: 99.01%, Test Accuracy: 90.53%
# Epoch [29/30], Loss: 0.0380, Train Accuracy: 98.89%, Test Accuracy: 87.68%
# Epoch [30/30], Loss: 0.0335, Train Accuracy: 98.99%, Test Accuracy: 90.74%

# %%
#FINAL CODE

# %%
import os
import torch
import torchvision.transforms as transforms
from torchvision.datasets import ImageFolder
from torch.utils.data import DataLoader
import torch.nn as nn
import torch.optim as optim
from torchvision.models import mobilenet_v3_small
from torch.utils.tensorboard import SummaryWriter
from torch.nn.utils import prune

# Set device
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# Data paths
preprocessed_data_dir = r'C:\Users\Asus\Desktop\Pre-processed'
train_dir = os.path.join(preprocessed_data_dir, 'train')
test_dir = os.path.join(preprocessed_data_dir, 'test')

# Image size and batch size
img_size = (224, 224)
batch_size = 32

# Define transformations
transform = transforms.Compose([
    transforms.Resize(img_size),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])  # Normalization for ImageNet
])

# Load datasets
train_dataset = ImageFolder(train_dir, transform=transform)
test_dataset = ImageFolder(test_dir, transform=transform)

train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

# Load MobileNetV3
model = mobilenet_v3_small(pretrained=True)

# Replace the classifier layer (no Dropout)
model.classifier[3] = nn.Linear(model.classifier[3].in_features, len(train_dataset.classes))

# Save the pre-pruned model state
torch.save(model.state_dict(), 'mobilenetv3_pre_no_regularization.pth')

# Move model to the device
model.to(device)

# Define loss function and optimizer (no regularization)
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001, weight_decay=0.0)  # No weight decay

# Define learning rate scheduler
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=10, gamma=0.1)

# Define a function to apply pruning to more layers
def apply_pruning(model):
    # Apply pruning to Conv2d and Linear layers
    for name, module in model.named_modules():
        if isinstance(module, nn.Conv2d) or isinstance(module, nn.Linear):
            parameters_to_prune = (
                (module, 'weight'),
            )
            prune.global_unstructured(
                parameters_to_prune,
                pruning_method=prune.L1Unstructured,
                amount=0.4,
            )

# Function to remove pruning masks and retain only non-zero weights
def remove_pruning(model):
    for name, module in model.named_modules():
        if isinstance(module, nn.Linear) or isinstance(module, nn.Conv2d):
            if hasattr(module, 'weight_orig'):  # Check if the layer is pruned
                prune.remove(module, 'weight')

# Function to test the model and return accuracy
def test_model(model, data_loader):
    model.eval()
    correct = 0
    total = 0
    with torch.no_grad():
        for images, labels in data_loader:
            images, labels = images.to(device), labels.to(device)
            outputs = model(images)
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
    return 100 * correct / total

# Train the model
num_epochs = 30
writer = SummaryWriter()

for epoch in range(num_epochs):
    model.train()
    running_loss = 0.0
    correct_train = 0
    total_train = 0

    for images, labels in train_loader:
        images, labels = images.to(device), labels.to(device)
        
        optimizer.zero_grad()
        
        # Forward pass
        outputs = model(images)
        loss = criterion(outputs, labels)
        
        # Backward pass and optimize
        loss.backward()
        optimizer.step()
        
        running_loss += loss.item()

        # Calculate training accuracy
        _, predicted = torch.max(outputs.data, 1)
        total_train += labels.size(0)
        correct_train += (predicted == labels).sum().item()

    avg_loss = running_loss / len(train_loader)
    train_accuracy = 100 * correct_train / total_train
    writer.add_scalar('Loss/train', avg_loss, epoch)
    writer.add_scalar('Accuracy/train', train_accuracy, epoch)

    # Test the model
    test_accuracy = test_model(model, test_loader)
    writer.add_scalar('Accuracy/test', test_accuracy, epoch)

    print(f'Epoch [{epoch+1}/{num_epochs}], Loss: {avg_loss:.4f}, Train Accuracy: {train_accuracy:.2f}%, Test Accuracy: {test_accuracy:.2f}%, Learning Rate: {scheduler.get_last_lr()[0]:.6f}')

    # Step the scheduler at the end of each epoch
    scheduler.step()

# Save the model before pruning
torch.save(model.state_dict(), 'beforePRUNING_no_regularization.pth')
before_pruning_train_accuracy = test_model(model, train_loader)
before_pruning_test_accuracy = test_model(model, test_loader)

# Apply pruning after training
apply_pruning(model)

# Remove pruning masks (to permanently eliminate zero weights)
remove_pruning(model)

# Save the pruned model (only non-zero weights)
sparse_model_path = 'afterPRUNING_sparse_no_regularization.pth'
sparse_state_dict = {}
for name, param in model.state_dict().items():
    # Retain only non-zero weights
    sparse_state_dict[name] = param[param != 0] if param.dim() > 1 else param

# Save the pruned model in a more compact format
torch.save(sparse_state_dict, sparse_model_path)

# Calculate accuracies after pruning
after_pruning_train_accuracy = test_model(model, train_loader)
after_pruning_test_accuracy = test_model(model, test_loader)

# Log the model sizes and accuracies
pre_pruning_size = os.path.getsize('mobilenetv3_pre_no_regularization.pth') / 1024  # KB
post_pruning_size = os.path.getsize(sparse_model_path) / 1024  # KB

print(f"Model Size Before Pruning: {pre_pruning_size:.2f} KB")
print(f"Model Size After Pruning: {post_pruning_size:.2f} KB")
print(f"Train Accuracy Before Pruning: {before_pruning_train_accuracy:.2f}%")
print(f"Test Accuracy Before Pruning: {before_pruning_test_accuracy:.2f}%")
print(f"Train Accuracy After Pruning: {after_pruning_train_accuracy:.2f}%")
print(f"Test Accuracy After Pruning: {after_pruning_test_accuracy:.2f}%")

writer.close()
# Out:
# Epoch [1/30], Loss: 0.4202, Train Accuracy: 86.29%, Test Accuracy: 83.62%, Learning Rate: 0.001000
# Epoch [2/30], Loss: 0.2020, Train Accuracy: 93.44%, Test Accuracy: 87.04%, Learning Rate: 0.001000
# Epoch [3/30], Loss: 0.1481, Train Accuracy: 95.16%, Test Accuracy: 90.46%, Learning Rate: 0.001000
# Epoch [4/30], Loss: 0.1265, Train Accuracy: 95.67%, Test Accuracy: 85.61%, Learning Rate: 0.001000
# Epoch [5/30], Loss: 0.0967, Train Accuracy: 96.73%, Test Accuracy: 88.82%, Learning Rate: 0.001000
# Epoch [6/30], Loss: 0.0838, Train Accuracy: 97.42%, Test Accuracy: 91.17%, Learning Rate: 0.001000
# Epoch [7/30], Loss: 0.0697, Train Accuracy: 97.77%, Test Accuracy: 89.74%, Learning Rate: 0.001000
# Epoch [8/30], Loss: 0.0734, Train Accuracy: 97.54%, Test Accuracy: 86.97%, Learning Rate: 0.001000
# Epoch [9/30], Loss: 0.0861, Train Accuracy: 97.29%, Test Accuracy: 85.83%, Learning Rate: 0.001000
# Epoch [10/30], Loss: 0.0662, Train Accuracy: 97.72%, Test Accuracy: 87.82%, Learning Rate: 0.001000
# Epoch [11/30], Loss: 0.0312, Train Accuracy: 98.94%, Test Accuracy: 92.31%, Learning Rate: 0.000100
# Epoch [12/30], Loss: 0.0137, Train Accuracy: 99.66%, Test Accuracy: 92.81%, Learning Rate: 0.000100
# Epoch [13/30], Loss: 0.0075, Train Accuracy: 99.78%, Test Accuracy: 93.23%, Learning Rate: 0.000100
# Epoch [14/30], Loss: 0.0068, Train Accuracy: 99.82%, Test Accuracy: 93.09%, Learning Rate: 0.000100
# Epoch [15/30], Loss: 0.0057, Train Accuracy: 99.76%, Test Accuracy: 92.74%, Learning Rate: 0.000100
# Epoch [16/30], Loss: 0.0032, Train Accuracy: 99.91%, Test Accuracy: 92.95%, Learning Rate: 0.000100
# Epoch [17/30], Loss: 0.0041, Train Accuracy: 99.88%, Test Accuracy: 92.88%, Learning Rate: 0.000100
# Epoch [18/30], Loss: 0.0032, Train Accuracy: 99.91%, Test Accuracy: 93.45%, Learning Rate: 0.000100
# Epoch [19/30], Loss: 0.0041, Train Accuracy: 99.88%, Test Accuracy: 93.45%, Learning Rate: 0.000100
# Epoch [20/30], Loss: 0.0026, Train Accuracy: 99.93%, Test Accuracy: 93.45%, Learning Rate: 0.000100
# Epoch [21/30], Loss: 0.0022, Train Accuracy: 99.94%, Test Accuracy: 93.66%, Learning Rate: 0.000010
# Epoch [22/30], Loss: 0.0025, Train Accuracy: 99.93%, Test Accuracy: 93.87%, Learning Rate: 0.000010
# Epoch [23/30], Loss: 0.0023, Train Accuracy: 99.90%, Test Accuracy: 93.87%, Learning Rate: 0.000010
# Epoch [24/30], Loss: 0.0023, Train Accuracy: 99.91%, Test Accuracy: 93.95%, Learning Rate: 0.000010
# Epoch [25/30], Loss: 0.0023, Train Accuracy: 99.92%, Test Accuracy: 93.80%, Learning Rate: 0.000010
# Epoch [26/30], Loss: 0.0019, Train Accuracy: 99.96%, Test Accuracy: 93.87%, Learning Rate: 0.000010
# Epoch [27/30], Loss: 0.0016, Train Accuracy: 99.97%, Test Accuracy: 93.80%, Learning Rate: 0.000010
# Epoch [28/30], Loss: 0.0016, Train Accuracy: 99.95%, Test Accuracy: 94.02%, Learning Rate: 0.000010
# Epoch [29/30], Loss: 0.0017, Train Accuracy: 99.95%, Test Accuracy: 93.87%, Learning Rate: 0.000010
# Epoch [30/30], Loss: 0.0021, Train Accuracy: 99.92%, Test Accuracy: 93.87%, Learning Rate: 0.000010
# Model Size Before Pruning: 6102.56 KB
# Model Size After Pruning: 3734.53 KB
# Train Accuracy Before Pruning: 99.97%
# Test Accuracy Before Pruning: 93.87%
# Train Accuracy After Pruning: 63.16%
# Test Accuracy After Pruning: 52.56%

# %%
#TESTING THE MODEL

# %%
from torchvision import transforms
from torchvision.datasets import ImageFolder
from torch.utils.data import DataLoader
from PIL import Image
import torch
import torch.nn as nn
from torchvision.models import mobilenet_v3_small
import os

# Set device
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# Data directory and transform
preprocessed_data_dir = r'C:\Users\Asus\Desktop\Pre-processed'
train_dir = os.path.join(preprocessed_data_dir, 'train')

# Define transformations
transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

# Load dataset to get class names
train_dataset = ImageFolder(train_dir, transform=transform)

# Load the model
def load_model(model_path, num_classes):
    model = mobilenet_v3_small(pretrained=False)  # Initialize model structure
    model.classifier[3] = nn.Linear(model.classifier[3].in_features, num_classes)  # Update classifier for your classes
    model.load_state_dict(torch.load(model_path))  # Load your trained weights
    model.to(device)  # Move model to the device
    model.eval()  # Set model to evaluation mode
    return model

# Function to preprocess and predict on a single image
def predict_image(image_path, model, transform):
    # Open image
    image = Image.open(image_path).convert("RGB")
    
    # Apply transformations
    image = transform(image)
    
    # Add batch dimension
    image = image.unsqueeze(0).to(device)  # Shape [1, 3, 224, 224]
    
    # Forward pass
    with torch.no_grad():
        output = model(image)
        _, predicted = torch.max(output, 1)
    
    # Map the predicted index to the class name
    class_name = train_dataset.classes[predicted.item()]
    return class_name

# Paths to model and test image
model_path = 'afterPRUNING_no_mask.pth'  # Path to the desired model file
test_image_path = r"C:\Users\Asus\Desktop\archive(3)\test_before\apse\bell_tower\1235.jpg"

# Load model and make a prediction
model = load_model(model_path, num_classes=len(train_dataset.classes))
predicted_class = predict_image(test_image_path, model, transform)

print(f"Predicted class: {predicted_class}")
# Out:
# C:\Users\Asus\anaconda3\Lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
# C:\Users\Asus\AppData\Local\Temp\ipykernel_25484\1048173841.py:31: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(model_path))  # Load your trained weights
# Predicted class: bell_tower

# %%
from torchvision import transforms
from torchvision.datasets import ImageFolder
from torch.utils.data import DataLoader
from PIL import Image
import torch
import torch.nn as nn
from torchvision.models import mobilenet_v3_small
import os

# Set device
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# Data directory and transform
preprocessed_data_dir = r'C:\Users\Asus\Desktop\Pre-processed'
train_dir = os.path.join(preprocessed_data_dir, 'train')

# Define transformations
transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

# Load dataset to get class names
train_dataset = ImageFolder(train_dir, transform=transform)

# Load the model
def load_model(model_path, num_classes):
    model = mobilenet_v3_small(pretrained=False)  # Initialize model structure
    model.classifier[3] = nn.Linear(model.classifier[3].in_features, num_classes)  # Update classifier for your classes
    model.load_state_dict(torch.load(model_path))  # Load your trained weights
    model.to(device)  # Move model to the device
    model.eval()  # Set model to evaluation mode
    return model

# Function to preprocess and predict on a single image
def predict_image(image_path, model, transform):
    # Open image
    image = Image.open(image_path).convert("RGB")
    
    # Apply transformations
    image = transform(image)
    
    # Add batch dimension
    image = image.unsqueeze(0).to(device)  # Shape [1, 3, 224, 224]
    
    # Forward pass
    with torch.no_grad():
        output = model(image)
        _, predicted = torch.max(output, 1)
    
    # Map the predicted index to the class name
    class_name = train_dataset.classes[predicted.item()]
    return class_name

# Paths to model and test image
model_path = 'afterPRUNING_no_mask.pth'  # Path to the desired model file
test_image_path = r"C:\Users\Asus\Desktop\archive(3)\test_before\column\360.jpg"

# Load model and make a prediction
model = load_model(model_path, num_classes=len(train_dataset.classes))
predicted_class = predict_image(test_image_path, model, transform)

print(f"Predicted class: {predicted_class}")
# Out:
# C:\Users\Asus\anaconda3\Lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# C:\Users\Asus\anaconda3\Lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
# C:\Users\Asus\AppData\Local\Temp\ipykernel_25728\560929638.py:31: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(model_path))  # Load your trained weights
# Predicted class: column

# %%
from torchvision import transforms
from torchvision.datasets import ImageFolder
from torch.utils.data import DataLoader
from PIL import Image
import torch
import torch.nn as nn
from torchvision.models import mobilenet_v3_small
import os

# Set device
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# Data directory and transform
preprocessed_data_dir = r'C:\Users\Asus\Desktop\Pre-processed'
train_dir = os.path.join(preprocessed_data_dir, 'train')

# Define transformations
transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

# Load dataset to get class names
train_dataset = ImageFolder(train_dir, transform=transform)

# Load the model
def load_model(model_path, num_classes):
    model = mobilenet_v3_small(pretrained=False)  # Initialize model structure
    model.classifier[3] = nn.Linear(model.classifier[3].in_features, num_classes)  # Update classifier for your classes
    model.load_state_dict(torch.load(model_path))  # Load your trained weights
    model.to(device)  # Move model to the device
    model.eval()  # Set model to evaluation mode
    return model

# Function to preprocess and predict on a single image
def predict_image(image_path, model, transform):
    # Open image
    image = Image.open(image_path).convert("RGB")
    
    # Apply transformations
    image = transform(image)
    
    # Add batch dimension
    image = image.unsqueeze(0).to(device)  # Shape [1, 3, 224, 224]
    
    # Forward pass
    with torch.no_grad():
        output = model(image)
        _, predicted = torch.max(output, 1)
    
    # Map the predicted index to the class name
    class_name = train_dataset.classes[predicted.item()]
    return class_name

# Paths to model and test image
model_path = 'afterPRUNING_no_mask.pth'  # Path to the desired model file
test_image_path = r"C:\Users\Asus\Desktop\archive(3)\test_before\gargoyle\994.jpg"

# Load model and make a prediction
model = load_model(model_path, num_classes=len(train_dataset.classes))
predicted_class = predict_image(test_image_path, model, transform)

print(f"Predicted class: {predicted_class}")
# Out:
# Predicted class: gargoyle
# C:\Users\Asus\AppData\Local\Temp\ipykernel_23228\3889065494.py:31: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(model_path))  # Load your trained weights
